# %% [markdown]
# # Introduction:
#
# ### Python Imports

# %%
import os
import tqdm
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data loaders for .mot files

# %%
# Data loader for .mot files

def read_header(mot_file,header_line=10): 
    if not os.path.isfile(mot_file): 
        return []

    try:         
        with open(mot_file, 'r') as f:
            lines = f.readlines()
            headers = lines[header_line]
            headers = headers.split()
            return headers
    except Exception as e:
        print(f"Unable to load headers for file:{mot_file}. Error:{e}")
        return [] 

def storage_to_numpy(storage_file, excess_header_entries=0):
    """Returns the data from a storage file in a numpy format. Skips all lines
    up to and including the line that says 'endheader'.
    Parameters
    ----------
    storage_file : str
        Path to an OpenSim Storage (.sto) file.
    Returns
    -------
    data : np.ndarray (or numpy structure array or something?)
        Contains all columns from the storage file, indexable by column name.
    excess_header_entries : int, optional
        If the header row has more names in it than there are data columns.
        We'll ignore this many header row entries from the end of the header
        row. This argument allows for a hacky fix to an issue that arises from
        Static Optimization '.sto' outputs.
    Examples
    --------
    Columns from the storage file can be obtained as follows:
        >>> data = storage2numpy('<filename>')
        >>> data['ground_force_vy']
    """
    # What's the line number of the line containing 'endheader'?
    f = open(storage_file, 'r')

    header_line = False
    for i, line in enumerate(f):
        if header_line:
            column_names = line.split()
            break
        if line.count('endheader') != 0:
            line_number_of_line_containing_endheader = i + 1
            header_line = True
    f.close()
    # With this information, go get the data.
    if excess_header_entries == 0:
        names = True
        skip_header = line_number_of_line_containing_endheader
    else:
        names = column_names[:-excess_header_entries]
        skip_header = line_number_of_line_containing_endheader + 1
    data = np.genfromtxt(storage_file, names=names,
            skip_header=skip_header)

    new_data = []
    for d in data:
        new_data.append(list(d))
    new_data = np.array(new_data)

    return data


def storage_to_dataframe(storage_file, headers):
    # Extract data
    data = storage_to_numpy(storage_file)
    data = np.array(data)
    new_data = []
    for d in data:
        new_data.append(list(d))
    new_data = np.array(new_data)
    header_mapping = {header:i for i,header in enumerate(headers)}

    out = pd.DataFrame(data=data['time'], columns=['time'])
    for count, header in enumerate(headers):
        out.insert(count + 1, header, new_data[:,count+1])    
    
    return out

# %% [markdown]
# # Load simulation data into a dictionary called subjects

# %%
data_path ='/media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/'

# Load simulation for data for given list of sessions
def load_simulation_data(mcs_sessions):
    subjects = {}

    for subject_name in tqdm.tqdm(mcs_sessions):

        if not os.path.isdir(os.path.join(data_path, subject_name)): continue
        simulation_results_path = os.path.join(data_path, subject_name, 'OpenSimData','Dynamics')

        if not os.path.isdir(simulation_results_path):
            continue
        
        subject = {}
        for trial_name in os.listdir(simulation_results_path): 
            
            if 'segment' not in trial_name: # Contains same results as segment-1 
                continue
            
            trial = {}
            
            kinetics_path = os.path.join(simulation_results_path, trial_name,f"kinetics_{trial_name}_muscle_driven.mot")
            mot_headers = read_header(kinetics_path,header_line=6)            
                        
            if len(mot_headers) == 0:
                print(f"Unable to load headers for file:", subject_name,trial_name, kinetics_path)
                continue 
            
            # Remove time from headers
            mot_headers.remove('time')

            kinetics = storage_to_dataframe(kinetics_path, mot_headers)
            
            trial['kinetics'] = kinetics

            kinematics_path = os.path.join(simulation_results_path, trial_name,f"kinematics_activations_{trial_name}_muscle_driven.mot")
            mot_headers = read_header(kinematics_path,header_line=10)

            if len(mot_headers) == 0:
                print(f"Unable to load headers for file:", subject_name,kinematics_path)
                continue 
            # print("Headers:", mot_headers)
            # Remove time from headers
            mot_headers.remove('time')

            kinematics = storage_to_dataframe(kinematics_path, mot_headers)
            trial['kinematics'] = kinematics

            subject['dof_names'] = kinematics.columns.tolist()    
            
            surrogate_results_path = os.path.join(os.path.dirname(os.path.dirname(data_path)), 'surrogate_output', f'{subject_name}_{trial_name.replace("_segment","")}.mot')
            if os.path.isfile(surrogate_results_path):
                mot_headers = read_header(surrogate_results_path,header_line=10)
                if len(mot_headers) == 0:
                    print(f"Unable to load surrogate headers for file:", subject_name,trial_name, surrogate_results_path)
                    continue 
                print("Headers:", mot_headers)
                # Remove time from headers
                mot_headers.remove('time')

                surrogate = storage_to_dataframe(surrogate_results_path, mot_headers)
                trial['surrogate'] = surrogate
            
            if len(trial) > 0:
                subject[trial_name] = trial        
                print("Loaded data for:", subject_name, trial_name, "Kinetics:", subject[trial_name]['kinetics'].shape, "Kinematics:", subject[trial_name]['kinematics'].shape)            

        if len(subject) > 0:
            subjects[subject_name] = subject
        else: 
            print("No trials found for subject:", subject_name)
    
    return subjects 


# PPE Files containing with MCS Scores
mcs_sessions = ["349e4383-da38-4138-8371-9a5fed63a56a","015b7571-9f0b-4db4-a854-68e57640640d","c613945f-1570-4011-93a4-8c8c6408e2cf","dfda5c67-a512-4ca2-a4b3-6a7e22599732","7562e3c0-dea8-46f8-bc8b-ed9d0f002a77","275561c0-5d50-4675-9df1-733390cd572f","0e10a4e3-a93f-4b4d-9519-d9287d1d74eb","a5e5d4cd-524c-4905-af85-99678e1239c8","dd215900-9827-4ae6-a07d-543b8648b1da","3d1207bf-192b-486a-b509-d11ca90851d7","c28e768f-6e2b-4726-8919-c05b0af61e4a","fb6e8f87-a1cc-48b4-8217-4e8b160602bf","e6b10bbf-4e00-4ac0-aade-68bc1447de3e","d66330dc-7884-4915-9dbb-0520932294c4","0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45","2345d831-6038-412e-84a9-971bc04da597","0a959024-3371-478a-96da-bf17b1da15a9","ef656fe8-27e7-428a-84a9-deb868da053d","c08f1d89-c843-4878-8406-b6f9798a558e","d2020b0e-6d41-4759-87f0-5c158f6ab86a","8dc21218-8338-4fd4-8164-f6f122dc33d9"]
mcs_scores = [4,4,2,3,2,4,3,3,2,3,4,3,4,2,2,3,4,4,3,3,3 ]
mcs_scores = dict(zip(mcs_sessions,mcs_scores))


# mcs_sessions = os.listdir(data_path)


PPE_Subjects = ["PPE09182201","PPE09182202","PPE09182203","PPE09182204","PPE09182205","PPE09182206","PPE09182207","PPE09182208","PPE09182209","PPE091822010","PPE09182211","PPE09182212","PPE09182213","PPE09182214","PPE09182215","PPE09182216","PPE09182217","PPE09182218","PPE09182219","PPE09182220","PPE09182221"]
PPE_Subjects = dict(zip(mcs_sessions,PPE_Subjects))

# import pandas as pd
# subject2opencap = pd.read_table('/media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/subject2opencap.txt',sep=',')
# subject2opencap
# PPE_Subjects = dict(zip( subject2opencap[' OpenCap-ID'].tolist(), subject2opencap['PPE'].tolist()))

# for session in PPE_Subjects:
#     if session not in mcs_scores:
#         mcs_scores[session] = -1  
#     print(session, PPE_Subjects[session], mcs_scores[session])

subjects = load_simulation_data(mcs_sessions[::-1])
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# Unable to load headers for file: 8dc21218-8338-4fd4-8164-f6f122dc33d9 SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/8dc21218-8338-4fd4-8164-f6f122dc33d9/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 8dc21218-8338-4fd4-8164-f6f122dc33d9 SQT01_segment_2 Kinetics: (109, 34) Kinematics: (110, 114)
#   5%|▍         | 1/21 [00:01<00:28,  1.44s/it]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 8dc21218-8338-4fd4-8164-f6f122dc33d9 SQT01_segment_3 Kinetics: (110, 34) Kinematics: (111, 114)
#  10%|▉         | 2/21 [00:01<00:13,  1.40it/s]
# Unable to load headers for file: d2020b0e-6d41-4759-87f0-5c158f6ab86a SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/d2020b0e-6d41-4759-87f0-5c158f6ab86a/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
# Unable to load headers for file: d2020b0e-6d41-4759-87f0-5c158f6ab86a SQT01_segment_2 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/d2020b0e-6d41-4759-87f0-5c158f6ab86a/OpenSimData/Dynamics/SQT01_segment_2/kinetics_SQT01_segment_2_muscle_driven.mot
# Unable to load headers for file: d2020b0e-6d41-4759-87f0-5c158f6ab86a SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/d2020b0e-6d41-4759-87f0-5c158f6ab86a/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
# No trials found for subject: d2020b0e-6d41-4759-87f0-5c158f6ab86a
# Unable to load headers for file: c08f1d89-c843-4878-8406-b6f9798a558e SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/c08f1d89-c843-4878-8406-b6f9798a558e/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: c08f1d89-c843-4878-8406-b6f9798a558e SQT01_segment_2 Kinetics: (116, 34) Kinematics: (117, 114)
#  14%|█▍        | 3/21 [00:02<00:14,  1.21it/s]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: c08f1d89-c843-4878-8406-b6f9798a558e SQT01_segment_3 Kinetics: (110, 34) Kinematics: (111, 114)
# Unable to load headers for file: ef656fe8-27e7-428a-84a9-deb868da053d SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/ef656fe8-27e7-428a-84a9-deb868da053d/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
#  19%|█▉        | 4/21 [00:02<00:09,  1.76it/s]
# Unable to load headers for file: ef656fe8-27e7-428a-84a9-deb868da053d SQT01_segment_2 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/ef656fe8-27e7-428a-84a9-deb868da053d/OpenSimData/Dynamics/SQT01_segment_2/kinetics_SQT01_segment_2_muscle_driven.mot
# Unable to load headers for file: ef656fe8-27e7-428a-84a9-deb868da053d SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/ef656fe8-27e7-428a-84a9-deb868da053d/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
# No trials found for subject: ef656fe8-27e7-428a-84a9-deb868da053d
#  24%|██▍       | 5/21 [00:03<00:07,  2.15it/s]
# Unable to load headers for file: 0a959024-3371-478a-96da-bf17b1da15a9 SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/0a959024-3371-478a-96da-bf17b1da15a9/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
# Unable to load headers for file: 0a959024-3371-478a-96da-bf17b1da15a9 SQT01_segment_2 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/0a959024-3371-478a-96da-bf17b1da15a9/OpenSimData/Dynamics/SQT01_segment_2/kinetics_SQT01_segment_2_muscle_driven.mot
# Unable to load headers for file: 0a959024-3371-478a-96da-bf17b1da15a9 SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/0a959024-3371-478a-96da-bf17b1da15a9/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
# No trials found for subject: 0a959024-3371-478a-96da-bf17b1da15a9
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 2345d831-6038-412e-84a9-971bc04da597 SQT01_segment_1 Kinetics: (137, 34) Kinematics: (138, 114)
#  29%|██▊       | 6/21 [00:03<00:08,  1.68it/s]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 2345d831-6038-412e-84a9-971bc04da597 SQT01_segment_2 Kinetics: (113, 34) Kinematics: (114, 114)
# Unable to load headers for file: 2345d831-6038-412e-84a9-971bc04da597 SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/2345d831-6038-412e-84a9-971bc04da597/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
# Unable to load headers for file: 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45 SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45 SQT01_segment_2 Kinetics: (127, 34) Kinematics: (128, 114)
#  33%|███▎      | 7/21 [00:04<00:10,  1.36it/s]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45 SQT01_segment_3 Kinetics: (120, 34) Kinematics: (121, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: d66330dc-7884-4915-9dbb-0520932294c4 SQT01_segment_1 Kinetics: (116, 34) Kinematics: (117, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: d66330dc-7884-4915-9dbb-0520932294c4 SQT01_segment_2 Kinetics: (105, 34) Kinematics: (106, 114)
#  38%|███▊      | 8/21 [00:06<00:11,  1.16it/s]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: d66330dc-7884-4915-9dbb-0520932294c4 SQT01_segment_3 Kinetics: (105, 34) Kinematics: (106, 114)
#  43%|████▎     | 9/21 [00:06<00:08,  1.33it/s]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: e6b10bbf-4e00-4ac0-aade-68bc1447de3e SQT01_segment_1 Kinetics: (127, 34) Kinematics: (128, 114)
# Unable to load headers for file: e6b10bbf-4e00-4ac0-aade-68bc1447de3e SQT01_segment_2 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/e6b10bbf-4e00-4ac0-aade-68bc1447de3e/OpenSimData/Dynamics/SQT01_segment_2/kinetics_SQT01_segment_2_muscle_driven.mot
# Unable to load headers for file: e6b10bbf-4e00-4ac0-aade-68bc1447de3e SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/e6b10bbf-4e00-4ac0-aade-68bc1447de3e/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
#  48%|████▊     | 10/21 [00:06<00:06,  1.74it/s]
# Unable to load headers for file: fb6e8f87-a1cc-48b4-8217-4e8b160602bf SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/fb6e8f87-a1cc-48b4-8217-4e8b160602bf/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
# Unable to load headers for file: fb6e8f87-a1cc-48b4-8217-4e8b160602bf SQT01_segment_2 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/fb6e8f87-a1cc-48b4-8217-4e8b160602bf/OpenSimData/Dynamics/SQT01_segment_2/kinetics_SQT01_segment_2_muscle_driven.mot
# Unable to load headers for file: fb6e8f87-a1cc-48b4-8217-4e8b160602bf SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/fb6e8f87-a1cc-48b4-8217-4e8b160602bf/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
# No trials found for subject: fb6e8f87-a1cc-48b4-8217-4e8b160602bf
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: c28e768f-6e2b-4726-8919-c05b0af61e4a SQT01_segment_1 Kinetics: (112, 34) Kinematics: (113, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: c28e768f-6e2b-4726-8919-c05b0af61e4a SQT01_segment_2 Kinetics: (100, 34) Kinematics: (101, 114)
#  52%|█████▏    | 11/21 [00:08<00:08,  1.23it/s]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: c28e768f-6e2b-4726-8919-c05b0af61e4a SQT01_segment_3 Kinetics: (99, 34) Kinematics: (100, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 3d1207bf-192b-486a-b509-d11ca90851d7 SQT01_segment_1 Kinetics: (141, 34) Kinematics: (142, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 3d1207bf-192b-486a-b509-d11ca90851d7 SQT01_segment_2 Kinetics: (141, 34) Kinematics: (142, 114)
#  57%|█████▋    | 12/21 [00:09<00:08,  1.02it/s]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 3d1207bf-192b-486a-b509-d11ca90851d7 SQT01_segment_3 Kinetics: (117, 34) Kinematics: (118, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: dd215900-9827-4ae6-a07d-543b8648b1da SQT01_segment_1 Kinetics: (126, 34) Kinematics: (127, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: dd215900-9827-4ae6-a07d-543b8648b1da SQT01_segment_2 Kinetics: (128, 34) Kinematics: (129, 114)
#  62%|██████▏   | 13/21 [00:10<00:08,  1.09s/it]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: dd215900-9827-4ae6-a07d-543b8648b1da SQT01_segment_3 Kinetics: (134, 34) Kinematics: (135, 114)
# ...
# Loaded data for: 275561c0-5d50-4675-9df1-733390cd572f SQT01_segment_2 Kinetics: (143, 34) Kinematics: (144, 114)
# Unable to load headers for file: 275561c0-5d50-4675-9df1-733390cd572f SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/275561c0-5d50-4675-9df1-733390cd572f/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 SQT01_segment_1 Kinetics: (141, 34) Kinematics: (142, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 SQT01_segment_2 Kinetics: (137, 34) Kinematics: (138, 114)
#  81%|████████  | 17/21 [00:15<00:04,  1.16s/it]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 SQT01_segment_3 Kinetics: (154, 34) Kinematics: (155, 114)
# Unable to load headers for file: dfda5c67-a512-4ca2-a4b3-6a7e22599732 SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/dfda5c67-a512-4ca2-a4b3-6a7e22599732/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
#  90%|█████████ | 19/21 [00:15<00:01,  1.54it/s]
# Unable to load headers for file: dfda5c67-a512-4ca2-a4b3-6a7e22599732 SQT01_segment_2 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/dfda5c67-a512-4ca2-a4b3-6a7e22599732/OpenSimData/Dynamics/SQT01_segment_2/kinetics_SQT01_segment_2_muscle_driven.mot
# Unable to load headers for file: dfda5c67-a512-4ca2-a4b3-6a7e22599732 SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/dfda5c67-a512-4ca2-a4b3-6a7e22599732/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
# No trials found for subject: dfda5c67-a512-4ca2-a4b3-6a7e22599732
# Unable to load headers for file: c613945f-1570-4011-93a4-8c8c6408e2cf SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/c613945f-1570-4011-93a4-8c8c6408e2cf/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
# Unable to load headers for file: c613945f-1570-4011-93a4-8c8c6408e2cf SQT01_segment_2 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/c613945f-1570-4011-93a4-8c8c6408e2cf/OpenSimData/Dynamics/SQT01_segment_2/kinetics_SQT01_segment_2_muscle_driven.mot
# Unable to load headers for file: c613945f-1570-4011-93a4-8c8c6408e2cf SQT01_segment_3 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/c613945f-1570-4011-93a4-8c8c6408e2cf/OpenSimData/Dynamics/SQT01_segment_3/kinetics_SQT01_segment_3_muscle_driven.mot
# No trials found for subject: c613945f-1570-4011-93a4-8c8c6408e2cf
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 015b7571-9f0b-4db4-a854-68e57640640d SQT01_segment_1 Kinetics: (132, 34) Kinematics: (133, 114)
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 015b7571-9f0b-4db4-a854-68e57640640d SQT01_segment_2 Kinetics: (130, 34) Kinematics: (131, 114)
#  95%|█████████▌| 20/21 [00:17<00:00,  1.15it/s]
# Headers: ['time', 'addbrev_l/activation', 'addlong_l/activation', 'addmagDist_l/activation', 'addmagIsch_l/activation', 'addmagMid_l/activation', 'addmagProx_l/activation', 'bflh_l/activation', 'bfsh_l/activation', 'edl_l/activation', 'ehl_l/activation', 'fdl_l/activation', 'fhl_l/activation', 'gaslat_l/activation', 'gasmed_l/activation', 'glmax1_l/activation', 'glmax2_l/activation', 'glmax3_l/activation', 'glmed1_l/activation', 'glmed2_l/activation', 'glmed3_l/activation', 'glmin1_l/activation', 'glmin2_l/activation', 'glmin3_l/activation', 'grac_l/activation', 'iliacus_l/activation', 'perbrev_l/activation', 'perlong_l/activation', 'piri_l/activation', 'psoas_l/activation', 'recfem_l/activation', 'sart_l/activation', 'semimem_l/activation', 'semiten_l/activation', 'soleus_l/activation', 'tfl_l/activation', 'tibant_l/activation', 'tibpost_l/activation', 'vasint_l/activation', 'vaslat_l/activation', 'vasmed_l/activation', 'addbrev_r/activation', 'addlong_r/activation', 'addmagDist_r/activation', 'addmagIsch_r/activation', 'addmagMid_r/activation', 'addmagProx_r/activation', 'bflh_r/activation', 'bfsh_r/activation', 'edl_r/activation', 'ehl_r/activation', 'fdl_r/activation', 'fhl_r/activation', 'gaslat_r/activation', 'gasmed_r/activation', 'glmax1_r/activation', 'glmax2_r/activation', 'glmax3_r/activation', 'glmed1_r/activation', 'glmed2_r/activation', 'glmed3_r/activation', 'glmin1_r/activation', 'glmin2_r/activation', 'glmin3_r/activation', 'grac_r/activation', 'iliacus_r/activation', 'perbrev_r/activation', 'perlong_r/activation', 'piri_r/activation', 'psoas_r/activation', 'recfem_r/activation', 'sart_r/activation', 'semimem_r/activation', 'semiten_r/activation', 'soleus_r/activation', 'tfl_r/activation', 'tibant_r/activation', 'tibpost_r/activation', 'vasint_r/activation', 'vaslat_r/activation', 'vasmed_r/activation']
# Loaded data for: 015b7571-9f0b-4db4-a854-68e57640640d SQT01_segment_3 Kinetics: (131, 34) Kinematics: (132, 114)
# Loaded data for: 349e4383-da38-4138-8371-9a5fed63a56a SQT01_1_segment_1 Kinetics: (132, 34) Kinematics: (133, 114)
# Loaded data for: 349e4383-da38-4138-8371-9a5fed63a56a SQT01_1_segment_2 Kinetics: (123, 34) Kinematics: (124, 114)
# 100%|██████████| 21/21 [00:18<00:00,  1.15it/s]
# Loaded data for: 349e4383-da38-4138-8371-9a5fed63a56a SQT01_1_segment_3 Kinetics: (145, 34) Kinematics: (146, 114)
# Unable to load headers for file: 349e4383-da38-4138-8371-9a5fed63a56a SQT01_segment_1 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/349e4383-da38-4138-8371-9a5fed63a56a/OpenSimData/Dynamics/SQT01_segment_1/kinetics_SQT01_segment_1_muscle_driven.mot
# Unable to load headers for file: 349e4383-da38-4138-8371-9a5fed63a56a SQT01_segment_2 /media/shubh/Elements/RoseYu/UCSD-OpenCap-Fitness-Dataset/MCS_DATA/Data/349e4383-da38-4138-8371-9a5fed63a56a/OpenSimData/Dynamics/SQT01_segment_2/kinetics_SQT01_segment_2_muscle_driven.mot

# %%
print(f"Subjects Loaded:", len(subjects.keys()))
# Out:
# Subjects Loaded: 15

# %% [markdown]
# ## Plot temporal segmentation results

# %%
# Name Mappings from Github copilot
plot_names_mapping = {
    'lumbar_bending': 'Trunk Obliquity',
    'lumbar_extension': 'Trunk Tilt',
    'lumbar_rotation': 'Trunk Rotation',
    'pelvis_list': 'Pelvic Obliquity',
    'pelvis_tilt': 'Pelvic Tilt',
    'pelvis_rotation': 'Pelvic Rotation',
    'hip_adduction_l': 'Left Hip Ab/Adduction',
    'hip_flexion_l': 'Left Hip Flexion/Extension',
    'hip_rotation_l': 'Left Hip Rotation',
    'hip_adduction_r': 'Right Hip Ab/Adduction',
    'hip_flexion_r': 'Right Hip Flexion/Extension',
    'hip_rotation_r': 'Right Hip Rotation',
    'knee_angle_l': 'Left Knee Flexion/Extension',
    'knee_angle_r': 'Right Knee Flexion/Extension',
    'ankle_angle_l': 'Left Ankle Dorsi/Plantar',
    'ankle_angle_r': 'Right Ankle Dorsi/Plantar'
}

# %%
plot_muscle_activations_mapping = {
    'addbrev_l/activation': 'Adductor Brevis (Left)',
    'addlong_l/activation': 'Adductor Longus (Left)',
    'addmagDist_l/activation': 'Adductor Magnus Distal (Left)',
    'addmagIsch_l/activation': 'Adductor Magnus Ischial (Left)',
    'addmagMid_l/activation': 'Adductor Magnus Middle (Left)',
    'addmagProx_l/activation': 'Adductor Magnus Proximal (Left)',
    'bflh_l/activation': 'Biceps Femoris Long Head (Left)',
    'bfsh_l/activation': 'Biceps Femoris Short Head (Left)',
    'edl_l/activation': 'Extensor Digitorum Longus (Left)',
    'ehl_l/activation': 'Extensor Hallucis Longus (Left)',
    'fdl_l/activation': 'Flexor Digitorum Longus (Left)',
    'fhl_l/activation': 'Flexor Hallucis Longus (Left)',
    'gaslat_l/activation': 'Gastrocnemius Lateral (Left)',
    'gasmed_l/activation': 'Gastrocnemius Medial (Left)',
    'glmax1_l/activation': 'Gluteus Maximus 1 (Left)',
    'glmax2_l/activation': 'Gluteus Maximus 2 (Left)',
    'glmax3_l/activation': 'Gluteus Maximus 3 (Left)',
    'glmed1_l/activation': 'Gluteus Medius 1 (Left)',
    'glmed2_l/activation': 'Gluteus Medius 2 (Left)',
    'glmed3_l/activation': 'Gluteus Medius 3 (Left)',
    'glmin1_l/activation': 'Gluteus Minimus 1 (Left)',
    'glmin2_l/activation': 'Gluteus Minimus 2 (Left)',
    'glmin3_l/activation': 'Gluteus Minimus 3 (Left)',
    'grac_l/activation': 'Gracilis (Left)',
    'iliacus_l/activation': 'Iliacus (Left)',
    'perbrev_l/activation': 'Peroneus Brevis (Left)',
    'perlong_l/activation': 'Peroneus Longus (Left)',
    'piri_l/activation': 'Piriformis (Left)',
    'psoas_l/activation': 'Psoas (Left)',
    'recfem_l/activation': 'Rectus Femoris (Left)',
    'sart_l/activation': 'Sartorius (Left)',
    'semimem_l/activation': 'Semimembranosus (Left)',
    'semiten_l/activation': 'Semitendinosus (Left)',
    'soleus_l/activation': 'Soleus (Left)',
    'tfl_l/activation': 'Tensor Fasciae Latae (Left)',
    'tibant_l/activation': 'Tibialis Anterior (Left)',
    'tibpost_l/activation': 'Tibialis Posterior (Left)',
    'vasint_l/activation': 'Vastus Intermedius (Left)',
    'vaslat_l/activation': 'Vastus Lateralis (Left)',
    'vasmed_l/activation': 'Vastus Medialis (Left)',
    'addbrev_r/activation': 'Adductor Brevis (Right)',
    'addlong_r/activation': 'Adductor Longus (Right)',
    'addmagDist_r/activation': 'Adductor Magnus Distal (Right)',
    'addmagIsch_r/activation': 'Adductor Magnus Ischial (Right)',
    'addmagMid_r/activation': 'Adductor Magnus Middle (Right)',
    'addmagProx_r/activation': 'Adductor Magnus Proximal (Right)',
    'bflh_r/activation': 'Biceps Femoris Long Head (Right)',
    'bfsh_r/activation': 'Biceps Femoris Short Head (Right)',
    'edl_r/activation': 'Extensor Digitorum Longus (Right)',
    'ehl_r/activation': 'Extensor Hallucis Longus (Right)',
    'fdl_r/activation': 'Flexor Digitorum Longus (Right)',
    'fhl_r/activation': 'Flexor Hallucis Longus (Right)',
    'gaslat_r/activation': 'Gastrocnemius Lateral (Right)',
    'gasmed_r/activation': 'Gastrocnemius Medial (Right)',
    'glmax1_r/activation': 'Gluteus Maximus 1 (Right)',
    'glmax2_r/activation': 'Gluteus Maximus 2 (Right)',
    'glmax3_r/activation': 'Gluteus Maximus 3 (Right)',
    'glmed1_r/activation': 'Gluteus Medius 1 (Right)',
    'glmed2_r/activation': 'Gluteus Medius 2 (Right)',
    'glmed3_r/activation': 'Gluteus Medius 3 (Right)',
    'glmin1_r/activation': 'Gluteus Minimus 1 (Right)',
    'glmin2_r/activation': 'Gluteus Minimus 2 (Right)',
    'glmin3_r/activation': 'Gluteus Minimus 3 (Right)',
    'grac_r/activation': 'Gracilis (Right)',
    'iliacus_r/activation': 'Iliacus (Right)',
    'perbrev_r/activation': 'Peroneus Brevis (Right)',
    'perlong_r/activation': 'Peroneus Longus (Right)',
    'piri_r/activation': 'Piriformis (Right)',
    'psoas_r/activation': 'Psoas (Right)',
    'recfem_r/activation': 'Rectus Femoris (Right)',
    'sart_r/activation': 'Sartorius (Right)',
    'semimem_r/activation': 'Semimembranosus (Right)',
    'semiten_r/activation': 'Semitendinosus (Right)',
    'soleus_r/activation': 'Soleus (Right)',
    'tfl_r/activation': 'Tensor Fasciae Latae (Right)',
    'tibant_r/activation': 'Tibialis Anterior (Right)',
    'tibpost_r/activation': 'Tibialis Posterior (Right)',
    'vasint_r/activation': 'Vastus Intermedius (Right)',
    'vaslat_r/activation': 'Vastus Lateralis (Right)',
    'vasmed_r/activation': 'Vastus Medialis (Right)'
}

from collections import defaultdict

# Group muscles by their base name (without _l or _r)
grouped_muscles = defaultdict(list)
for key in plot_muscle_activations_mapping.keys():
    base_name = key.split('_')[0]
    grouped_muscles[base_name].append(key)

# Create a list of muscle pairs
muscle_pairs = []
for base_name, keys in grouped_muscles.items():
    if len(keys) == 2:  # Ensure both left and right muscles are present
        muscle_pairs.append((keys[0], keys[1]))
        
# Number of muscle pairs per page (3 columns * 3 rows)
num_pairs_per_page = 5 * 2

# Split muscle pairs into groups for each page
pages = [muscle_pairs[i:i + num_pairs_per_page] for i in range(0, len(muscle_pairs), num_pairs_per_page)]

# Create dictionaries for each page
plot_muscle_activations_mapping_pages = []
for page in pages:
    page_dict = {}
    for left_key, right_key in page:
        page_dict[left_key] = plot_muscle_activations_mapping[left_key]
        page_dict[right_key] = plot_muscle_activations_mapping[right_key]
    plot_muscle_activations_mapping_pages.append(page_dict)

# Print the dictionaries for each page
for i, page_dict in enumerate(plot_muscle_activations_mapping_pages):
    print(f"Muscle Activation Page {i + 1}:")
    print(page_dict)
    print()
# Out:
# Muscle Activation Page 1:
# {'addbrev_l/activation': 'Adductor Brevis (Left)', 'addbrev_r/activation': 'Adductor Brevis (Right)', 'addlong_l/activation': 'Adductor Longus (Left)', 'addlong_r/activation': 'Adductor Longus (Right)', 'addmagDist_l/activation': 'Adductor Magnus Distal (Left)', 'addmagDist_r/activation': 'Adductor Magnus Distal (Right)', 'addmagIsch_l/activation': 'Adductor Magnus Ischial (Left)', 'addmagIsch_r/activation': 'Adductor Magnus Ischial (Right)', 'addmagMid_l/activation': 'Adductor Magnus Middle (Left)', 'addmagMid_r/activation': 'Adductor Magnus Middle (Right)', 'addmagProx_l/activation': 'Adductor Magnus Proximal (Left)', 'addmagProx_r/activation': 'Adductor Magnus Proximal (Right)', 'bflh_l/activation': 'Biceps Femoris Long Head (Left)', 'bflh_r/activation': 'Biceps Femoris Long Head (Right)', 'bfsh_l/activation': 'Biceps Femoris Short Head (Left)', 'bfsh_r/activation': 'Biceps Femoris Short Head (Right)', 'edl_l/activation': 'Extensor Digitorum Longus (Left)', 'edl_r/activation': 'Extensor Digitorum Longus (Right)', 'ehl_l/activation': 'Extensor Hallucis Longus (Left)', 'ehl_r/activation': 'Extensor Hallucis Longus (Right)'}
#
# Muscle Activation Page 2:
# {'fdl_l/activation': 'Flexor Digitorum Longus (Left)', 'fdl_r/activation': 'Flexor Digitorum Longus (Right)', 'fhl_l/activation': 'Flexor Hallucis Longus (Left)', 'fhl_r/activation': 'Flexor Hallucis Longus (Right)', 'gaslat_l/activation': 'Gastrocnemius Lateral (Left)', 'gaslat_r/activation': 'Gastrocnemius Lateral (Right)', 'gasmed_l/activation': 'Gastrocnemius Medial (Left)', 'gasmed_r/activation': 'Gastrocnemius Medial (Right)', 'glmax1_l/activation': 'Gluteus Maximus 1 (Left)', 'glmax1_r/activation': 'Gluteus Maximus 1 (Right)', 'glmax2_l/activation': 'Gluteus Maximus 2 (Left)', 'glmax2_r/activation': 'Gluteus Maximus 2 (Right)', 'glmax3_l/activation': 'Gluteus Maximus 3 (Left)', 'glmax3_r/activation': 'Gluteus Maximus 3 (Right)', 'glmed1_l/activation': 'Gluteus Medius 1 (Left)', 'glmed1_r/activation': 'Gluteus Medius 1 (Right)', 'glmed2_l/activation': 'Gluteus Medius 2 (Left)', 'glmed2_r/activation': 'Gluteus Medius 2 (Right)', 'glmed3_l/activation': 'Gluteus Medius 3 (Left)', 'glmed3_r/activation': 'Gluteus Medius 3 (Right)'}
#
# Muscle Activation Page 3:
# {'glmin1_l/activation': 'Gluteus Minimus 1 (Left)', 'glmin1_r/activation': 'Gluteus Minimus 1 (Right)', 'glmin2_l/activation': 'Gluteus Minimus 2 (Left)', 'glmin2_r/activation': 'Gluteus Minimus 2 (Right)', 'glmin3_l/activation': 'Gluteus Minimus 3 (Left)', 'glmin3_r/activation': 'Gluteus Minimus 3 (Right)', 'grac_l/activation': 'Gracilis (Left)', 'grac_r/activation': 'Gracilis (Right)', 'iliacus_l/activation': 'Iliacus (Left)', 'iliacus_r/activation': 'Iliacus (Right)', 'perbrev_l/activation': 'Peroneus Brevis (Left)', 'perbrev_r/activation': 'Peroneus Brevis (Right)', 'perlong_l/activation': 'Peroneus Longus (Left)', 'perlong_r/activation': 'Peroneus Longus (Right)', 'piri_l/activation': 'Piriformis (Left)', 'piri_r/activation': 'Piriformis (Right)', 'psoas_l/activation': 'Psoas (Left)', 'psoas_r/activation': 'Psoas (Right)', 'recfem_l/activation': 'Rectus Femoris (Left)', 'recfem_r/activation': 'Rectus Femoris (Right)'}
#
# Muscle Activation Page 4:
# {'sart_l/activation': 'Sartorius (Left)', 'sart_r/activation': 'Sartorius (Right)', 'semimem_l/activation': 'Semimembranosus (Left)', 'semimem_r/activation': 'Semimembranosus (Right)', 'semiten_l/activation': 'Semitendinosus (Left)', 'semiten_r/activation': 'Semitendinosus (Right)', 'soleus_l/activation': 'Soleus (Left)', 'soleus_r/activation': 'Soleus (Right)', 'tfl_l/activation': 'Tensor Fasciae Latae (Left)', 'tfl_r/activation': 'Tensor Fasciae Latae (Right)', 'tibant_l/activation': 'Tibialis Anterior (Left)', 'tibant_r/activation': 'Tibialis Anterior (Right)', 'tibpost_l/activation': 'Tibialis Posterior (Left)', 'tibpost_r/activation': 'Tibialis Posterior (Right)', 'vasint_l/activation': 'Vastus Intermedius (Left)', 'vasint_r/activation': 'Vastus Intermedius (Right)', 'vaslat_l/activation': 'Vastus Lateralis (Left)', 'vaslat_r/activation': 'Vastus Lateralis (Right)', 'vasmed_l/activation': 'Vastus Medialis (Left)', 'vasmed_r/activation': 'Vastus Medialis (Right)'}

# %%
def get_plotting_data(subject,trial,remove_headers=['pelvis_tx','pelvis_ty','pelvis_tz']): 
    # Get the subject data and remove pelvis translation 

    headers = subject['dof_names'] 

    keep_index = [headers.index(header)  for header in plot_names_mapping.keys()]

    plot_headers = [headers[i] for i in keep_index]

    plot_data = {}
    plot_data['kinematics'] = subject[trial]['kinematics'] 
    plot_data['kinematics'] = plot_data['kinematics'][plot_headers]


    plot_headers_kinetics = [ h +'_moment'  for h in plot_headers]
    plot_data['kinetics'] = subject[trial]['kinetics'] 
    plot_data['kinetics'] = plot_data['kinetics'][plot_headers_kinetics]




    for page_index, page_dict in enumerate(plot_muscle_activations_mapping_pages):
        plot_muscle_activations_index = [headers.index(header) for header in page_dict.keys()]
        plot_muscle_activations_headers = [headers[i] for i in plot_muscle_activations_index]
        plot_data[f'muscle_activations-{page_index}'] = subject[trial]['kinematics'][plot_muscle_activations_headers]

        if 'surrogate' in subject[trial]:
            plot_data[f'muscle_activations-surrogate-{page_index}'] = subject[trial]['surrogate'][plot_muscle_activations_headers]    
        else: 
            plot_data[f'muscle_activations-surrogate-{page_index}'] = np.zeros_like(plot_data[f'muscle_activations-{page_index}'])    


    for k in plot_data:
        if 'muscle_activations' in k or 'surrogate' in k:
            mc_page_index = int(k.split('-')[-1])
            assert plot_data[k].shape[-1] == len(plot_muscle_activations_mapping_pages[mc_page_index]), f"Length of headers should match headers length. Found:{plot_data[k].shape[-1]} , expected:{plot_muscle_activations_mapping_pages[mc_page_index]}"
        else: 
            assert plot_data[k].shape[-1] == len(plot_headers), f"Length of headers should match headers length. Found:{plot_data[k].shape[-1]} , expected:{len(plot_headers)}"

        if type(plot_data[k]) != np.ndarray:
            plot_data[k] = plot_data[k].to_numpy()



    return plot_headers, plot_data

# get_plotting_data(subjects["015b7571-9f0b-4db4-a854-68e57640640d"],'SQT01_segment_3')

# %% [markdown]
# ## Temporal Segmentation

# %%
import math
import plotly

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Temporal Segmentation
from scipy.signal import savgol_filter
from scipy.signal import find_peaks

from scipy.interpolate import CubicSpline


def time_normalization(time_series,duration=101): 

    orig_time_space = np.linspace(0,1,len(time_series))
        
    spline = CubicSpline(orig_time_space, time_series)

    spline_input = np.linspace(0,1,duration)
    split_output = spline(spline_input)
            
    return split_output

def find_valleys_in_max_angular_velocity(max_angular_velocity,seconds_per_frame=0.01,allowed_height_difference_threshold=0.1):
    """
        Find peaks in the angular velocity of a time series of rotation vectors.

        Args:
        angular_velocity: A numpy array of shape (N, 24) containing angular velocities in radians per second.
        framerate: The frame rate of the data in Hz.

        Returns: A numpy array of shape (M,) containing the indices of the peaks in the angular velocity.
    """

    diff = np.max(max_angular_velocity) - np.min(max_angular_velocity)
    min_height = np.min(max_angular_velocity) + allowed_height_difference_threshold*diff

    distance_between_valleys = max(1,int(1/(10*seconds_per_frame)))
    # distance_between_valleys = 1

    print(f"distance between valleys={distance_between_valleys}")
    print(f"Max allowed valley height={min_height} allowed_height_difference_threshold={allowed_height_difference_threshold}")
    valleys, meta_data = find_peaks(-max_angular_velocity,distance=distance_between_valleys,height=-min_height)

    print("Valleys",valleys, "Meta data: ",meta_data)

    return valleys


def find_best_n_segments(temporal_segmentation_data, num_segments, duplicate_threshold=0.75, rms_threshold=0.75):
    """
        Validate segments using DTW

    """

    for trial in temporal_segmentation_data:

        max_pose_velocity = temporal_segmentation_data[trial]['max_pose_velocity']
        valleys = temporal_segmentation_data[trial]['change_points']
        

        if len(valleys) < num_segments -1 : continue

        if len(valleys) > 25: 
            valleys = np.sort(np.random.choice(valleys,25,replace=False))

        # Add first and last frame for completeness
        valleys = [0] + list(valleys) + [len(max_pose_velocity)-1]
        valleys = np.array(valleys)

        # In some cases there could a single valley which defines the start and the stop cycle. 
        # If that is the case, we need to duplicate the valley
        # Check if a particular valley is too far to the adjacent valleys. If so, duplicate it.
        # If the distance between the two adjacent valleys is greater than 1/2*average segment duaration, duplicate the valley 
        valley_copys = []
        valley_threshold = (len(max_pose_velocity)/num_segments)*duplicate_threshold
        for i,v in enumerate(valleys):
            if i == 0: continue
            if i == len(valleys)-1: continue 


            if (valleys[i+1] - valleys[i])  > valley_threshold and (valleys[i] - valleys[i-1])  > valley_threshold: 
                valley_copys.append(valleys[i])
        
        valleys = np.concatenate([valleys,valley_copys]).astype(int)
        valleys.sort()


        # Start-Stop candidates
        print(f"Start-Stop Candidates for {trial_name}",valleys)
        temporal_segmentation_data[trial]['change_points'] = valleys

    # from tslearn.barycenters import dtw_barycenter_averaging
    from itertools import combinations

    best_combination = {} 
    best_combination_score = np.inf
    best_combination_data = ()


    ## Hard tests for filtet out invalid combinations 
    rms_sequence = np.sqrt(np.sum(max_pose_velocity**2)) # RMS for entire sequence. If some segment has motion less than the 1/2*num_segments, probably no motion is happening in it.  
    
    for trial in temporal_segmentation_data:
        valleys = temporal_segmentation_data[trial]['change_points']
        max_pose_velocity = temporal_segmentation_data[trial]['max_pose_velocity']
        
        for cur_comb in combinations(valleys, 2*num_segments):
        
            segments = [    [cur_comb[i*2 + 0],cur_comb[i*2 + 1]] for i in range(num_segments)    ]

            rms_segments = [np.sqrt(np.sum(max_pose_velocity[segment[0]:segment[1]]**2)) for segment in segments]

            if np.min(rms_segments) < rms_sequence*rms_threshold/num_segments:
                continue

            print("Testing segments",segments,"RMS Sequence:", rms_sequence,"RMS Threshold:",rms_sequence*rms_threshold/num_segments)
            print(rms_segments)

            if 'valid_segments' not in temporal_segmentation_data[trial]: 
                temporal_segmentation_data[trial]['valid_segments'] = []
            
            temporal_segmentation_data[trial]['valid_segments'].append(segments)
    
    
    def compute_combination_score(combination): 
        
        print(f"Computing combination score:{combination}")
        time_series = []
        for trial in combination: 
            segments = combination[trial]   
            max_pose_velocity = temporal_segmentation_data[trial]['max_pose_velocity']
            # Normalize Time Series
            time_normalized_series = np.array([time_normalization(max_pose_velocity[segment[0]:segment[1]]) for segment in segments])
            time_series.append(time_normalized_series)
        # Minimize STD at for entire duration
        combination_score = np.sum(np.std(time_series,axis=0))
        
        return combination_score        
    
    # Sort the trial names in data
    trials_names = sorted([k for k in temporal_segmentation_data], key=lambda x : int(x.split('_')[-1]))
    
    # Run recursion on all trials and return the combinations with the best matching score acrross trials. on all valid combinations. If num_combiations 
    def dfs(ind, combination):
        if ind == len(temporal_segmentation_data): 
            combination_score = compute_combination_score(combination)
            return combination, combination_score
            
        trial_name = trials_names[ind] 
        if 'valid_segments' not in temporal_segmentation_data[trial_name] or len(temporal_segmentation_data[trial_name]['valid_segments']) == 0:
            return dfs(ind+1, combination)
        
        print(f"{ind} combinations:{combinations}")
        
        best_combination_score = np.inf
        best_combination = None
        for trial_combination in temporal_segmentation_data[trial_name]['valid_segments']: 
            combination[trial_name] = trial_combination
            combination, combination_score = dfs(ind+1, combination)
            
            
            if combination_score < best_combination_score: 
                best_combination_score = combination_score
                best_combination = combination.copy()
        
            del combination[trial_name] # Remove combination, try another combination
        
        print(f"Best Score for: {ind} {best_combination_score} best_combination:{best_combination} ")
        
        return best_combination, best_combination_score
                     
    best_combination, best_combination_score = dfs(0, {}) 
    
    if np.isinf(best_combination_score):
        print("Could not find a valid segments. All combinations below RMS threshold") 
        return {}, np.inf
        
    return best_combination,best_combination_score


def temporal_segementation(data,headers, seconds_per_frame=0.01,visualize=True,num_segments=5,allowed_height_difference_threshold=0.1,fig_title=None,isdeg=True):
    """
        Find segments in the angular velocity of a time series of rotation vectors.
        params:
            data: A dictionary containing the pose_params

        returns: 
            segments: A list of tuples containing the start and end indices of the segments.
    """
    trials_names = sorted([k for k in data], key=lambda x : int(x.split('_')[-1])) 
 
    # Create subplots
    fig = plotly.subplots.make_subplots(rows=2, cols=len(data), subplot_titles=[ f"{trial_index}. Start-Stop:{trial_name} " for trial_index, trial_name in enumerate(trials_names)])
    
    temporal_segmentation_data = {} 
    
    # Sort the trial names in data


    for trial_index, trial_name in enumerate(trials_names):
        
        print(f"Finding valleys in For {trial_index}:{trial_name}")
        
        pose_velocity = plot_data[trial_name]['kinematics']
        
        print(f"  Time series: {pose_velocity.shape}")

        
        # Smoothing Filter ## Note window length and polyorder should be adjusted based on the data
        for i in range(len(headers)): 
            pose_velocity[:,i] = savgol_filter(pose_velocity[:,i], window_length=21, polyorder=3)

        # Only consider knee joints kinematics
        knee_indices = [i for i,header in enumerate(headers) if "knee" in header.lower()]
        max_pose_velocity = np.max(pose_velocity[:,knee_indices],axis=1)

        x = np.arange(len(max_pose_velocity))*seconds_per_frame

        if not isdeg:
            max_pose_velocity = np.rad2deg(max_pose_velocity)

        for i in range(len(headers)): 
            fig.add_trace(go.Scatter(
                x=x,
                y=pose_velocity[:,i],
                mode='lines',
                name=plot_headers[i],
                showlegend=True),row=1,col=trial_index+1)

        fig.add_trace(go.Scatter(
            x=x,
            y=max_pose_velocity,
            mode='lines',
            name='Knee Kinematics',
            showlegend=False
        ),row=2,col=trial_index+1)
        
        change_points = find_valleys_in_max_angular_velocity(max_pose_velocity,seconds_per_frame=seconds_per_frame,allowed_height_difference_threshold=allowed_height_difference_threshold)
        
        fig.add_trace(go.Scatter(
            x=x[change_points],
            y=max_pose_velocity[change_points],
            mode='markers',
            marker=dict(
                color='red',
                size=16,
                symbol='arrow-up'
            ),
            name='change_points'
        ),row=2,col=trial_index+1)
            
        temporal_segmentation_data[trial_name] = {'change_points':change_points, 'max_pose_velocity': max_pose_velocity}
    
    # fig.show()
        
    segments_all_trial,segment_score = find_best_n_segments(temporal_segmentation_data,num_segments=num_segments)
    
            
    for trial_index, trial_name in enumerate(trials_names):

        change_points = temporal_segmentation_data[trial_name]['change_points']
        max_pose_velocity = temporal_segmentation_data[trial_name]['max_pose_velocity']
        segments = np.array(segments_all_trial[trial_name])

        print(segments,trial_name)

        x = np.arange(len(max_pose_velocity))*seconds_per_frame

        if not isdeg:
            max_pose_velocity = np.rad2deg(max_pose_velocity)
        
        # Plot the line segments 
        if not np.isinf(segment_score): 
            empty_array = np.array([None]*segments.shape[0]).reshape((-1,1))
            plot_y_segments = np.tile( np.max(max_pose_velocity).reshape((1,1)), segments.shape )
            plot_y_segments = np.concatenate([plot_y_segments,empty_array],axis=1).reshape(-1)

            plot_x_segments = np.concatenate([segments*seconds_per_frame,empty_array],axis=1).reshape(-1)

            fig.add_trace(go.Scatter(
                x=plot_x_segments,
                y=plot_y_segments,
                line_shape='linear',
                name='Selected Segments'
            ),row=2,col=trial_index+1)

        else: 
            segments = None


    # Update subplot titles
    fig.update_layout(
        title_text=fig_title if fig_title != '' or fig_title is not None else f'Temporal Segmentation using Knee Kinematics',
        font=dict(family="Times New Roman"),
    )
 
    # Set figure size
    fig.update_layout(width=1000, height=400)
    
    fig.update_xaxes(title_text="Time (s)", row=1, col=1)
    fig.update_yaxes(title_text="Max Knee Flexion (deg)", row=1, col=1)


    if visualize: 
        # Show the figure
        fig.show()

    # fig.write_image(image_path + "_angular.png")
    return fig, segments_all_trial



###############################################################

# skip_subjects = ["c08f1d89-c843-4878-8406-b6f9798a558e","0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45","c28e768f-6e2b-4726-8919-c05b0af61e4a","0e10a4e3-a93f-4b4d-9519-d9287d1d74eb","349e4383-da38-4138-8371-9a5fed63a56a"]
# skip_subjects = [mcs_sessions[0], mcs_sessions[1]]
skip_subjects = []
plot_headers = None
for subject_ind, subject_name in tqdm.tqdm(enumerate(mcs_sessions)):
    
    print(f"Evaluating Id: {subject_ind} Name: {subject_name}")
    
    if subject_name in skip_subjects: continue
    
    if subject_name not in subjects: 
        print(f"Subject not found in data:{subject_name}")
        continue
    
    if len(subjects[subject_name]) <= 1:  # If dict is empty skip.
        print(f"Subject is empty:{subjects[subject_name]}")    
        continue
    
    print(f" Data:{subjects[subject_name].keys()}")
    
    
     
    plot_data = {}

    # Get seconds per frame 
    seconds_per_frame = 0 

    for trial_name in subjects[subject_name]: 
        if trial_name == 'dof_names': continue
        
        if trial_name == 'seconds_per_frame': continue  
    

        if len(subjects[subject_name][trial_name]) <= 1:  # If dict is empty skip.
            print(f"Trial is empty:{subjects[subject_name][trial_name]}") 
            continue 
        print(subjects[subject_name][trial_name].keys())
    
        trial_length = subjects[subject_name][trial_name]['kinematics']['time'].iloc[-1] - subjects[subject_name][trial_name]['kinematics']['time'].iloc[0]
        if trial_length < 1: continue # Can't perform squat in less tha a second . 
        
        
        seconds_per_frame += trial_length
        
        plot_headers, plot_data[trial_name] = get_plotting_data(subjects[subject_name],trial_name)
        
        print(seconds_per_frame,subjects[subject_name][trial_name]['kinematics']['time'].iloc[-1],subjects[subject_name][trial_name]['kinematics']['time'].iloc[0])

        print(f"Subject:{subject_name} Trial Index:{trial_name} Length: {trial_length} Headers:{plot_headers}")

    if seconds_per_frame == 0: 
        print("Tracks are empty, skipping subject")
        continue

    assert seconds_per_frame > 0, f"Subject Index:{subject_ind} seconds_per_frame should be greater 0. Likely no trial found to evaluate." 
    
    seconds_per_frame /= sum([len(plot_data[trial_name]['kinematics']) for trial_name in plot_data])


    
    
    fig_title = f"Temporal Segmentation using Knee Kinematics for Subject:{subject_name}"

    num_segments = 1 # Number of segments per trial

    # Temporal Segmentation (using knee angles kinematics since it gave the most reasonable results) 
    segments_fig, segments_all_trials = temporal_segementation(plot_data,plot_headers,\
                                      num_segments=num_segments, seconds_per_frame=seconds_per_frame,\
                                      allowed_height_difference_threshold=0.15,\
                                      isdeg=True,visualize=False,fig_title=fig_title)



    os.makedirs("pdfs",exist_ok=True)
    plotly.io.write_image(segments_fig, f'pdfs/{PPE_Subjects[subject_name]}_segmentation.pdf', format='pdf')

    if len(segments_all_trials) == 0: 
        print("Could not find segments")
        continue  
    
    # Update data information
    for trial_name in segments_all_trials:
        subjects[subject_name][trial_name]['segments'] = segments_all_trials[trial_name]
    
    subjects[subject_name]['seconds_per_frame'] = seconds_per_frame
# Out:
# 0it [00:00, ?it/s]
# Evaluating Id: 0 Name: 349e4383-da38-4138-8371-9a5fed63a56a
#  Data:dict_keys(['dof_names', 'SQT01_1_segment_1', 'SQT01_1_segment_2', 'SQT01_1_segment_3'])
# dict_keys(['kinetics', 'kinematics'])
# 2.2 2.2 0.0
# Subject:349e4383-da38-4138-8371-9a5fed63a56a Trial Index:SQT01_1_segment_1 Length: 2.2 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics'])
# 4.25 4.4 2.35
# Subject:349e4383-da38-4138-8371-9a5fed63a56a Trial Index:SQT01_1_segment_2 Length: 2.0500000000000003 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics'])
# 6.666666670000001 6.95 4.53333333
# Subject:349e4383-da38-4138-8371-9a5fed63a56a Trial Index:SQT01_1_segment_3 Length: 2.4166666700000006 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_1_segment_1
#   Time series: (133, 16)
# distance between valleys=6
# Max allowed valley height=17.53371137926404 allowed_height_difference_threshold=0.15
# Valleys [  1 128] Meta data:  {'peak_heights': array([-1.63946931, -0.12449633])}
# Finding valleys in For 1:SQT01_1_segment_2
#   Time series: (124, 16)
# distance between valleys=6
# Max allowed valley height=15.921134609016672 allowed_height_difference_threshold=0.15
# Valleys [2] Meta data:  {'peak_heights': array([-0.39129574])}
# Finding valleys in For 2:SQT01_1_segment_3
#   Time series: (146, 16)
# distance between valleys=6
# Max allowed valley height=16.086233222985765 allowed_height_difference_threshold=0.15
# Valleys [  2 142] Meta data:  {'peak_heights': array([-0.34998649, -0.02686409])}
# Start-Stop Candidates for SQT01_1_segment_3 [  0   1 128 132]
# Start-Stop Candidates for SQT01_1_segment_3 [  0   2 123]
# Start-Stop Candidates for SQT01_1_segment_3 [  0   2 142 145]
# Testing segments [[0, 128]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [876.7650228046011]
# Testing segments [[0, 132]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [876.7657240040771]
# Testing segments [[1, 128]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [876.7623858124822]
# Testing segments [[1, 132]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [876.7630870140672]
# Testing segments [[0, 123]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [746.7430030468772]
# Testing segments [[2, 123]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [746.7413088478427]
# Testing segments [[0, 142]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [857.5887736734824]
# Testing segments [[0, 145]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [857.5887867667869]
# Testing segments [[2, 142]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [857.5884336340558]
# Testing segments [[2, 145]] RMS Sequence: 857.5888371595133 RMS Threshold: 643.191627869635
# [857.5884467273655]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_3': [[0, 142]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_3': [[0, 145]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_3': [[2, 142]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 2 457.0881166636792 best_combination:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_3': [[0, 142]], 'SQT01_1_segment_2': [[2, 123]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[0, 145]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 142]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 2 428.8860338729935 best_combination:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 1 428.8860338729935 best_combination:{'SQT01_1_segment_1': [[0, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_3': [[0, 142]], 'SQT01_1_segment_1': [[0, 132]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_3': [[0, 145]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_3': [[2, 142]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 2 377.2622898140615 best_combination:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_3': [[2, 145]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_3': [[0, 142]], 'SQT01_1_segment_2': [[2, 123]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[0, 145]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 142]]}
# Computing combination score:{'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 2 352.4440182767325 best_combination:{'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 1 352.4440182767325 best_combination:{'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_3': [[0, 142]], 'SQT01_1_segment_1': [[1, 128]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_3': [[0, 145]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_3': [[2, 142]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 2 475.8373726911053 best_combination:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_3': [[2, 145]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_3': [[0, 142]], 'SQT01_1_segment_2': [[2, 123]]}
# Computing combination score:{'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[0, 145]]}
# Computing combination score:{'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 142]]}
# Computing combination score:{'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 2 447.9924775039779 best_combination:{'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 1 447.9924775039779 best_combination:{'SQT01_1_segment_1': [[1, 128]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_3': [[0, 142]], 'SQT01_1_segment_1': [[1, 132]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_3': [[0, 145]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_3': [[2, 142]]}
# Computing combination score:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 2 399.049149082213 best_combination:{'SQT01_1_segment_2': [[0, 123]], 'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_3': [[2, 145]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_3': [[0, 142]], 'SQT01_1_segment_2': [[2, 123]]}
# Computing combination score:{'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[0, 145]]}
# Computing combination score:{'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 142]]}
# Computing combination score:{'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 2 375.64071474043715 best_combination:{'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 1 375.64071474043715 best_combination:{'SQT01_1_segment_1': [[1, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# Best Score for: 0 352.4440182767325 best_combination:{'SQT01_1_segment_1': [[0, 132]], 'SQT01_1_segment_2': [[2, 123]], 'SQT01_1_segment_3': [[2, 145]]}
# [[  0 132]] SQT01_1_segment_1
# [[  2 123]] SQT01_1_segment_2
# [[  2 145]] SQT01_1_segment_3
# 1it [00:02,  2.71s/it]
# Evaluating Id: 1 Name: 015b7571-9f0b-4db4-a854-68e57640640d
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 2.2 3.15 0.95
# Subject:015b7571-9f0b-4db4-a854-68e57640640d Trial Index:SQT01_segment_1 Length: 2.2 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 4.36666666 5.33333333 3.16666667
# Subject:015b7571-9f0b-4db4-a854-68e57640640d Trial Index:SQT01_segment_2 Length: 2.16666666 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 6.54999999 7.53333333 5.35
# Subject:015b7571-9f0b-4db4-a854-68e57640640d Trial Index:SQT01_segment_3 Length: 2.18333333 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_1
#   Time series: (133, 16)
# distance between valleys=6
# Max allowed valley height=15.820868760272221 allowed_height_difference_threshold=0.15
# Valleys [128] Meta data:  {'peak_heights': array([-0.34363192])}
# Finding valleys in For 1:SQT01_segment_2
#   Time series: (131, 16)
# distance between valleys=6
# Max allowed valley height=16.36905435449788 allowed_height_difference_threshold=0.15
# Valleys [] Meta data:  {'peak_heights': array([], dtype=float64)}
# Finding valleys in For 2:SQT01_segment_3
#   Time series: (132, 16)
# distance between valleys=6
# Max allowed valley height=16.452076646517018 allowed_height_difference_threshold=0.15
# Valleys [3] Meta data:  {'peak_heights': array([-0.63084295])}
# Start-Stop Candidates for SQT01_segment_3 [  0 128 132]
# Start-Stop Candidates for SQT01_segment_3 [  0 130]
# Start-Stop Candidates for SQT01_segment_3 [  0   3 131]
# Testing segments [[0, 128]] RMS Sequence: 716.0412542701611 RMS Threshold: 537.0309407026208
# [693.5501271167443]
# Testing segments [[0, 132]] RMS Sequence: 716.0412542701611 RMS Threshold: 537.0309407026208
# [693.5512408463709]
# Testing segments [[0, 130]] RMS Sequence: 716.0412542701611 RMS Threshold: 537.0309407026208
# [700.6252998335534]
# Testing segments [[0, 131]] RMS Sequence: 716.0412542701611 RMS Threshold: 537.0309407026208
# [716.0406988450432]
# Testing segments [[3, 131]] RMS Sequence: 716.0412542701611 RMS Threshold: 537.0309407026208
# [716.0392093598844]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 130]], 'SQT01_segment_3': [[0, 131]]}
# Computing combination score:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 130]], 'SQT01_segment_3': [[3, 131]]}
# Best Score for: 2 190.67593742368686 best_combination:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 130]], 'SQT01_segment_3': [[3, 131]]}
# Best Score for: 1 190.67593742368686 best_combination:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 130]], 'SQT01_segment_3': [[3, 131]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_2': [[0, 130]], 'SQT01_segment_3': [[0, 131]], 'SQT01_segment_1': [[0, 132]]}
# Computing combination score:{'SQT01_segment_2': [[0, 130]], 'SQT01_segment_1': [[0, 132]], 'SQT01_segment_3': [[3, 131]]}
# Best Score for: 2 191.3882330997059 best_combination:{'SQT01_segment_2': [[0, 130]], 'SQT01_segment_1': [[0, 132]], 'SQT01_segment_3': [[3, 131]]}
# Best Score for: 1 191.3882330997059 best_combination:{'SQT01_segment_2': [[0, 130]], 'SQT01_segment_1': [[0, 132]], 'SQT01_segment_3': [[3, 131]]}
# Best Score for: 0 190.67593742368686 best_combination:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 130]], 'SQT01_segment_3': [[3, 131]]}
# [[  0 128]] SQT01_segment_1
# [[  0 130]] SQT01_segment_2
# [[  3 131]] SQT01_segment_3
# 2it [00:03,  1.39s/it]
# Evaluating Id: 2 Name: c613945f-1570-4011-93a4-8c8c6408e2cf
# Subject not found in data:c613945f-1570-4011-93a4-8c8c6408e2cf
# Evaluating Id: 3 Name: dfda5c67-a512-4ca2-a4b3-6a7e22599732
# Subject not found in data:dfda5c67-a512-4ca2-a4b3-6a7e22599732
# Evaluating Id: 4 Name: 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 2.3499999999999996 12.03333333 9.68333333
# Subject:7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 Trial Index:SQT01_segment_1 Length: 2.3499999999999996 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 4.633333329999999 14.45 12.16666667
# Subject:7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 Trial Index:SQT01_segment_2 Length: 2.2833333299999996 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 7.19999999 17.03333333 14.46666667
# Subject:7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 Trial Index:SQT01_segment_3 Length: 2.566666660000001 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_1
#   Time series: (142, 16)
# distance between valleys=6
# Max allowed valley height=17.39718672940062 allowed_height_difference_threshold=0.15
# Valleys [139] Meta data:  {'peak_heights': array([-0.07177768])}
# Finding valleys in For 1:SQT01_segment_2
#   Time series: (138, 16)
# distance between valleys=6
# Max allowed valley height=17.410992293069544 allowed_height_difference_threshold=0.15
# Valleys [  4 131] Meta data:  {'peak_heights': array([-0.11977158, -0.01409704])}
# Finding valleys in For 2:SQT01_segment_3
#   Time series: (155, 16)
# distance between valleys=6
# Max allowed valley height=17.0306390654404 allowed_height_difference_threshold=0.15
# Valleys [  8 137] Meta data:  {'peak_heights': array([0.01061617, 0.10621563])}
# Start-Stop Candidates for SQT01_segment_3 [  0 139 141]
# Start-Stop Candidates for SQT01_segment_3 [  0   4 131 137]
# Start-Stop Candidates for SQT01_segment_3 [  0   8 137 154]
# Testing segments [[0, 139]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [794.4906968278808]
# Testing segments [[0, 141]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [794.4907116808929]
# Testing segments [[0, 131]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [795.3090946573367]
# Testing segments [[0, 137]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [795.3091154748282]
# Testing segments [[4, 131]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [795.3090675108432]
# Testing segments [[4, 137]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [795.3090883283354]
# Testing segments [[0, 137]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [789.308554449572]
# Testing segments [[0, 154]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [789.3085746138838]
# Testing segments [[8, 137]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [789.3085316557292]
# Testing segments [[8, 154]] RMS Sequence: 789.3085747220465 RMS Threshold: 591.9814310415348
# [789.3085518200417]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 131]], 'SQT01_segment_3': [[0, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 131]], 'SQT01_segment_3': [[0, 154]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 131]], 'SQT01_segment_3': [[8, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 131]], 'SQT01_segment_3': [[8, 154]]}
# Best Score for: 2 205.17809553362474 best_combination:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 131]], 'SQT01_segment_3': [[8, 137]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_3': [[0, 137]], 'SQT01_segment_2': [[0, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[0, 154]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[8, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[8, 154]]}
# Best Score for: 2 372.1475584563244 best_combination:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[8, 137]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_3': [[0, 137]], 'SQT01_segment_2': [[4, 131]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[4, 131]], 'SQT01_segment_3': [[0, 154]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[4, 131]], 'SQT01_segment_3': [[8, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[4, 131]], 'SQT01_segment_3': [[8, 154]]}
# Best Score for: 2 343.68705122015 best_combination:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[4, 131]], 'SQT01_segment_3': [[8, 137]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_3': [[0, 137]], 'SQT01_segment_2': [[4, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[4, 137]], 'SQT01_segment_3': [[0, 154]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[4, 137]], 'SQT01_segment_3': [[8, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[4, 137]], 'SQT01_segment_3': [[8, 154]]}
# Best Score for: 2 520.0348944670536 best_combination:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[4, 137]], 'SQT01_segment_3': [[0, 154]]}
# Best Score for: 1 205.17809553362474 best_combination:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 131]], 'SQT01_segment_3': [[8, 137]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_2': [[0, 131]], 'SQT01_segment_3': [[0, 137]], 'SQT01_segment_1': [[0, 141]]}
# Computing combination score:{'SQT01_segment_2': [[0, 131]], 'SQT01_segment_1': [[0, 141]], 'SQT01_segment_3': [[0, 154]]}
# Computing combination score:{'SQT01_segment_2': [[0, 131]], 'SQT01_segment_1': [[0, 141]], 'SQT01_segment_3': [[8, 137]]}
# Computing combination score:{'SQT01_segment_2': [[0, 131]], 'SQT01_segment_1': [[0, 141]], 'SQT01_segment_3': [[8, 154]]}
# Best Score for: 2 240.06241258841547 best_combination:{'SQT01_segment_2': [[0, 131]], 'SQT01_segment_1': [[0, 141]], 'SQT01_segment_3': [[8, 137]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_3': [[0, 137]], 'SQT01_segment_2': [[0, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[0, 154]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[8, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[8, 154]]}
# Best Score for: 2 337.9417806040552 best_combination:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[0, 154]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_3': [[0, 137]], 'SQT01_segment_2': [[4, 131]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[4, 131]], 'SQT01_segment_3': [[0, 154]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[4, 131]], 'SQT01_segment_3': [[8, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[4, 131]], 'SQT01_segment_3': [[8, 154]]}
# Best Score for: 2 364.62741849139593 best_combination:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[4, 131]], 'SQT01_segment_3': [[8, 137]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_3': [[0, 137]], 'SQT01_segment_2': [[4, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[4, 137]], 'SQT01_segment_3': [[0, 154]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[4, 137]], 'SQT01_segment_3': [[8, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[4, 137]], 'SQT01_segment_3': [[8, 154]]}
# Best Score for: 2 458.07871329241135 best_combination:{'SQT01_segment_1': [[0, 141]], 'SQT01_segment_2': [[4, 137]], 'SQT01_segment_3': [[0, 154]]}
# Best Score for: 1 240.06241258841547 best_combination:{'SQT01_segment_2': [[0, 131]], 'SQT01_segment_1': [[0, 141]], 'SQT01_segment_3': [[8, 137]]}
# Best Score for: 0 205.17809553362474 best_combination:{'SQT01_segment_1': [[0, 139]], 'SQT01_segment_2': [[0, 131]], 'SQT01_segment_3': [[8, 137]]}
# [[  0 139]] SQT01_segment_1
# [[  0 131]] SQT01_segment_2
# [[  8 137]] SQT01_segment_3
# 5it [00:03,  1.88it/s]
# Evaluating Id: 5 Name: 275561c0-5d50-4675-9df1-733390cd572f
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 2.23333333 2.23333333 0.0
# Subject:275561c0-5d50-4675-9df1-733390cd572f Trial Index:SQT01_segment_1 Length: 2.23333333 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 4.61666667 4.81666667 2.43333333
# Subject:275561c0-5d50-4675-9df1-733390cd572f Trial Index:SQT01_segment_2 Length: 2.38333334 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_1
#   Time series: (135, 16)
# distance between valleys=6
# Max allowed valley height=17.000538382705514 allowed_height_difference_threshold=0.15
# Valleys [128] Meta data:  {'peak_heights': array([-2.44736335])}
# Finding valleys in For 1:SQT01_segment_2
#   Time series: (144, 16)
# distance between valleys=6
# Max allowed valley height=15.181416437701188 allowed_height_difference_threshold=0.15
# Valleys [136] Meta data:  {'peak_heights': array([-0.54197165])}
# Start-Stop Candidates for SQT01_segment_2 [  0 128 134]
# Start-Stop Candidates for SQT01_segment_2 [  0 136 143]
# Testing segments [[0, 128]] RMS Sequence: 706.509107686066 RMS Threshold: 529.8818307645495
# [716.1087586389577]
# Testing segments [[0, 134]] RMS Sequence: 706.509107686066 RMS Threshold: 529.8818307645495
# [716.1419949334851]
# Testing segments [[0, 136]] RMS Sequence: 706.509107686066 RMS Threshold: 529.8818307645495
# [706.5071566560489]
# Testing segments [[0, 143]] RMS Sequence: 706.509107686066 RMS Threshold: 529.8818307645495
# [706.5088554580752]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 136]]}
# Computing combination score:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 143]]}
# Best Score for: 1 455.16193937490084 best_combination:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 143]]}
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_2': [[0, 136]], 'SQT01_segment_1': [[0, 134]]}
# Computing combination score:{'SQT01_segment_1': [[0, 134]], 'SQT01_segment_2': [[0, 143]]}
# Best Score for: 1 632.3467149260953 best_combination:{'SQT01_segment_1': [[0, 134]], 'SQT01_segment_2': [[0, 143]]}
# Best Score for: 0 455.16193937490084 best_combination:{'SQT01_segment_1': [[0, 128]], 'SQT01_segment_2': [[0, 143]]}
# [[  0 128]] SQT01_segment_1
# [[  0 143]] SQT01_segment_2
# 6it [00:04,  2.04it/s]
# Evaluating Id: 6 Name: 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 3.2499999999999996 4.78333333 1.53333333
# Subject:0e10a4e3-a93f-4b4d-9519-d9287d1d74eb Trial Index:SQT01_segment_1 Length: 3.2499999999999996 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 5.233333329999999 6.98333333 5.0
# Subject:0e10a4e3-a93f-4b4d-9519-d9287d1d74eb Trial Index:SQT01_segment_2 Length: 1.9833333299999998 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 7.78333333 9.98333333 7.43333333
# Subject:0e10a4e3-a93f-4b4d-9519-d9287d1d74eb Trial Index:SQT01_segment_3 Length: 2.5500000000000007 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_1
#   Time series: (196, 16)
# distance between valleys=6
# Max allowed valley height=18.905511992366662 allowed_height_difference_threshold=0.15
# Valleys [1] Meta data:  {'peak_heights': array([-3.07431385])}
# Finding valleys in For 1:SQT01_segment_2
#   Time series: (120, 16)
# distance between valleys=6
# Max allowed valley height=24.919051408434534 allowed_height_difference_threshold=0.15
# Valleys [  1 118] Meta data:  {'peak_heights': array([-9.40946385, -9.84368827])}
# Finding valleys in For 2:SQT01_segment_3
#   Time series: (154, 16)
# distance between valleys=6
# Max allowed valley height=17.581159767583074 allowed_height_difference_threshold=0.15
# Valleys [148] Meta data:  {'peak_heights': array([-1.22226535])}
# Start-Stop Candidates for SQT01_segment_3 [  0   1 195]
# Start-Stop Candidates for SQT01_segment_3 [  0   1 118 119]
# Start-Stop Candidates for SQT01_segment_3 [  0 148 153]
# Testing segments [[0, 195]] RMS Sequence: 829.9399210943577 RMS Threshold: 622.4549408207683
# [861.4228089737749]
# Testing segments [[1, 195]] RMS Sequence: 829.9399210943577 RMS Threshold: 622.4549408207683
# [861.4172360967731]
# Testing segments [[0, 118]] RMS Sequence: 829.9399210943577 RMS Threshold: 622.4549408207683
# [829.4150312877335]
# Testing segments [[0, 119]] RMS Sequence: 829.9399210943577 RMS Threshold: 622.4549408207683
# [829.47344280867]
# Testing segments [[1, 118]] RMS Sequence: 829.9399210943577 RMS Threshold: 622.4549408207683
# [829.3576580308493]
# Testing segments [[1, 119]] RMS Sequence: 829.9399210943577 RMS Threshold: 622.4549408207683
# [829.4160735922901]
# Testing segments [[0, 148]] RMS Sequence: 829.9399210943577 RMS Threshold: 622.4549408207683
# [829.9344669703092]
# Testing segments [[0, 153]] RMS Sequence: 829.9399210943577 RMS Threshold: 622.4549408207683
# [829.9390264596087]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_2': [[0, 118]], 'SQT01_segment_3': [[0, 148]]}
# Computing combination score:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_2': [[0, 118]], 'SQT01_segment_3': [[0, 153]]}
# Best Score for: 2 999.8923991229133 best_combination:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_2': [[0, 118]], 'SQT01_segment_3': [[0, 148]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[0, 119]]}
# Computing combination score:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_2': [[0, 119]], 'SQT01_segment_3': [[0, 153]]}
# Best Score for: 2 979.275080196269 best_combination:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[0, 119]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[1, 118]]}
# Computing combination score:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_2': [[1, 118]], 'SQT01_segment_3': [[0, 153]]}
# Best Score for: 2 1021.0209275977521 best_combination:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[1, 118]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[1, 119]]}
# Computing combination score:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_2': [[1, 119]], 'SQT01_segment_3': [[0, 153]]}
# Best Score for: 2 1000.7369623908414 best_combination:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[1, 119]]}
# Best Score for: 1 979.275080196269 best_combination:{'SQT01_segment_1': [[0, 195]], 'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[0, 119]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[0, 118]], 'SQT01_segment_1': [[1, 195]]}
# Computing combination score:{'SQT01_segment_2': [[0, 118]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_3': [[0, 153]]}
# Best Score for: 2 983.9836097391081 best_combination:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_2': [[0, 118]], 'SQT01_segment_1': [[1, 195]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[0, 119]]}
# Computing combination score:{'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[0, 119]], 'SQT01_segment_3': [[0, 153]]}
# Best Score for: 2 963.1116046230801 best_combination:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[0, 119]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[1, 118]]}
# Computing combination score:{'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[1, 118]], 'SQT01_segment_3': [[0, 153]]}
# Best Score for: 2 1005.0551038595216 best_combination:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[1, 118]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[1, 119]]}
# Computing combination score:{'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[1, 119]], 'SQT01_segment_3': [[0, 153]]}
# Best Score for: 2 984.5098285328551 best_combination:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[1, 119]]}
# Best Score for: 1 963.1116046230801 best_combination:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[0, 119]]}
# Best Score for: 0 963.1116046230801 best_combination:{'SQT01_segment_3': [[0, 148]], 'SQT01_segment_1': [[1, 195]], 'SQT01_segment_2': [[0, 119]]}
# [[  1 195]] SQT01_segment_1
# [[  0 119]] SQT01_segment_2
# [[  0 148]] SQT01_segment_3
# 7it [00:04,  2.09it/s]
# Evaluating Id: 7 Name: a5e5d4cd-524c-4905-af85-99678e1239c8
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 2.4000000000000004 2.66666667 0.26666667
# Subject:a5e5d4cd-524c-4905-af85-99678e1239c8 Trial Index:SQT01_segment_1 Length: 2.4000000000000004 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 4.683333340000001 4.96666667 2.68333333
# Subject:a5e5d4cd-524c-4905-af85-99678e1239c8 Trial Index:SQT01_segment_2 Length: 2.2833333400000004 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 6.933333340000001 7.23333333 4.98333333
# Subject:a5e5d4cd-524c-4905-af85-99678e1239c8 Trial Index:SQT01_segment_3 Length: 2.25 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_1
#   Time series: (145, 16)
# distance between valleys=6
# Max allowed valley height=18.70012229002958 allowed_height_difference_threshold=0.15
# Valleys [142] Meta data:  {'peak_heights': array([-3.66724591])}
# Finding valleys in For 1:SQT01_segment_2
#   Time series: (138, 16)
# distance between valleys=6
# Max allowed valley height=19.471837381751847 allowed_height_difference_threshold=0.15
# Valleys [  5 121] Meta data:  {'peak_heights': array([-4.48524868, -5.9228437 ])}
# Finding valleys in For 2:SQT01_segment_3
#   Time series: (136, 16)
# distance between valleys=6
# Max allowed valley height=17.214809928466167 allowed_height_difference_threshold=0.15
# Valleys [129] Meta data:  {'peak_heights': array([-2.78406931])}
# Start-Stop Candidates for SQT01_segment_3 [  0 142 144]
# Start-Stop Candidates for SQT01_segment_3 [  0   5 121 137]
# Start-Stop Candidates for SQT01_segment_3 [  0 129 135]
# Testing segments [[0, 142]] RMS Sequence: 634.9571467282401 RMS Threshold: 476.2178600461801
# [719.3180084338672]
# Testing segments [[0, 144]] RMS Sequence: 634.9571467282401 RMS Threshold: 476.2178600461801
# [719.3368258470792]
# Testing segments [[0, 121]] RMS Sequence: 634.9571467282401 RMS Threshold: 476.2178600461801
# [690.2952907603111]
# Testing segments [[0, 137]] RMS Sequence: 634.9571467282401 RMS Threshold: 476.2178600461801
# [690.6479722239902]
# Testing segments [[5, 121]] RMS Sequence: 634.9571467282401 RMS Threshold: 476.2178600461801
# [690.221759131677]
# Testing segments [[5, 137]] RMS Sequence: 634.9571467282401 RMS Threshold: 476.2178600461801
# [690.5744781485006]
# Testing segments [[0, 129]] RMS Sequence: 634.9571467282401 RMS Threshold: 476.2178600461801
# [634.9096841422702]
# Testing segments [[0, 135]] RMS Sequence: 634.9571467282401 RMS Threshold: 476.2178600461801
# [634.948996879139]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_2': [[0, 121]], 'SQT01_segment_3': [[0, 129]]}
# Computing combination score:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_2': [[0, 121]], 'SQT01_segment_3': [[0, 135]]}
# Best Score for: 2 798.1766966281249 best_combination:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_2': [[0, 121]], 'SQT01_segment_3': [[0, 129]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[0, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[0, 135]]}
# Best Score for: 2 261.3647473414696 best_combination:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[0, 137]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[5, 121]]}
# Computing combination score:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_2': [[5, 121]], 'SQT01_segment_3': [[0, 135]]}
# Best Score for: 2 643.9949118131658 best_combination:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[5, 121]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[5, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_2': [[5, 137]], 'SQT01_segment_3': [[0, 135]]}
# Best Score for: 2 250.2091374376661 best_combination:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[5, 137]]}
# Best Score for: 1 250.2091374376661 best_combination:{'SQT01_segment_1': [[0, 142]], 'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[5, 137]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[0, 121]], 'SQT01_segment_1': [[0, 144]]}
# Computing combination score:{'SQT01_segment_2': [[0, 121]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_3': [[0, 135]]}
# Best Score for: 2 821.6581501563819 best_combination:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_2': [[0, 121]], 'SQT01_segment_1': [[0, 144]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[0, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[0, 137]], 'SQT01_segment_3': [[0, 135]]}
# Best Score for: 2 249.29479520405488 best_combination:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[0, 137]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[5, 121]]}
# Computing combination score:{'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[5, 121]], 'SQT01_segment_3': [[0, 135]]}
# Best Score for: 2 668.3237714722205 best_combination:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[5, 121]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[5, 137]]}
# Computing combination score:{'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[5, 137]], 'SQT01_segment_3': [[0, 135]]}
# Best Score for: 2 211.94158144949108 best_combination:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[5, 137]]}
# Best Score for: 1 211.94158144949108 best_combination:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[5, 137]]}
# Best Score for: 0 211.94158144949108 best_combination:{'SQT01_segment_3': [[0, 129]], 'SQT01_segment_1': [[0, 144]], 'SQT01_segment_2': [[5, 137]]}
# [[  0 144]] SQT01_segment_1
# [[  5 137]] SQT01_segment_2
# [[  0 129]] SQT01_segment_3
# 8it [00:05,  2.03it/s]
# Evaluating Id: 8 Name: dd215900-9827-4ae6-a07d-543b8648b1da
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 2.0999999999999996 9.76666667 7.66666667
# Subject:dd215900-9827-4ae6-a07d-543b8648b1da Trial Index:SQT01_segment_1 Length: 2.0999999999999996 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 4.233333329999999 12.43333333 10.3
# Subject:dd215900-9827-4ae6-a07d-543b8648b1da Trial Index:SQT01_segment_2 Length: 2.1333333299999993 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 6.46666666 15.05 12.81666667
# Subject:dd215900-9827-4ae6-a07d-543b8648b1da Trial Index:SQT01_segment_3 Length: 2.2333333300000007 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_1
#   Time series: (127, 16)
# distance between valleys=6
# Max allowed valley height=17.80184156565107 allowed_height_difference_threshold=0.15
# Valleys [  1 124] Meta data:  {'peak_heights': array([-0.80062022, -0.49954021])}
# Finding valleys in For 1:SQT01_segment_2
#   Time series: (129, 16)
# distance between valleys=6
# Max allowed valley height=18.075642818938036 allowed_height_difference_threshold=0.15
# Valleys [] Meta data:  {'peak_heights': array([], dtype=float64)}
# Finding valleys in For 2:SQT01_segment_3
#   Time series: (135, 16)
# distance between valleys=6
# Max allowed valley height=18.346575729533484 allowed_height_difference_threshold=0.15
# Valleys [127] Meta data:  {'peak_heights': array([-0.82088189])}
# Start-Stop Candidates for SQT01_segment_3 [  0   1 124 126]
# Start-Stop Candidates for SQT01_segment_3 [  0 128]
# Start-Stop Candidates for SQT01_segment_3 [  0 127 134]
# Testing segments [[0, 124]] RMS Sequence: 838.0417142218342 RMS Threshold: 628.5312856663757
# [835.0660481059798]
# Testing segments [[0, 126]] RMS Sequence: 838.0417142218342 RMS Threshold: 628.5312856663757
# [835.0663783226189]
# Testing segments [[1, 124]] RMS Sequence: 838.0417142218342 RMS Threshold: 628.5312856663757
# [835.0656017445322]
# Testing segments [[1, 126]] RMS Sequence: 838.0417142218342 RMS Threshold: 628.5312856663757
# [835.0659319613478]
# Testing segments [[0, 128]] RMS Sequence: 838.0417142218342 RMS Threshold: 628.5312856663757
# [841.4743545476875]
# Testing segments [[0, 127]] RMS Sequence: 838.0417142218342 RMS Threshold: 628.5312856663757
# [838.0359528301038]
# Testing segments [[0, 134]] RMS Sequence: 838.0417142218342 RMS Threshold: 628.5312856663757
# [838.0410981970277]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 124]], 'SQT01_segment_2': [[0, 128]], 'SQT01_segment_3': [[0, 127]]}
# Computing combination score:{'SQT01_segment_1': [[0, 124]], 'SQT01_segment_2': [[0, 128]], 'SQT01_segment_3': [[0, 134]]}
# Best Score for: 2 357.2512476391798 best_combination:{'SQT01_segment_1': [[0, 124]], 'SQT01_segment_2': [[0, 128]], 'SQT01_segment_3': [[0, 134]]}
# Best Score for: 1 357.2512476391798 best_combination:{'SQT01_segment_1': [[0, 124]], 'SQT01_segment_2': [[0, 128]], 'SQT01_segment_3': [[0, 134]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_2': [[0, 128]], 'SQT01_segment_3': [[0, 127]], 'SQT01_segment_1': [[0, 126]]}
# Computing combination score:{'SQT01_segment_2': [[0, 128]], 'SQT01_segment_1': [[0, 126]], 'SQT01_segment_3': [[0, 134]]}
# Best Score for: 2 300.665293819206 best_combination:{'SQT01_segment_2': [[0, 128]], 'SQT01_segment_1': [[0, 126]], 'SQT01_segment_3': [[0, 134]]}
# Best Score for: 1 300.665293819206 best_combination:{'SQT01_segment_2': [[0, 128]], 'SQT01_segment_1': [[0, 126]], 'SQT01_segment_3': [[0, 134]]}
# 1 combinations:<class 'itertools.combinations'>
# 2 combinations:<class 'itertools.combinations'>
# ...
# Computing combination score:{'SQT01_segment_2': [[0, 105]], 'SQT01_segment_1': [[5, 116]], 'SQT01_segment_3': [[2, 105]]}
# Best Score for: 2 377.9725979937453 best_combination:{'SQT01_segment_2': [[0, 105]], 'SQT01_segment_1': [[5, 116]], 'SQT01_segment_3': [[2, 105]]}
# 2 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[5, 116]], 'SQT01_segment_3': [[0, 105]], 'SQT01_segment_2': [[4, 105]]}
# Computing combination score:{'SQT01_segment_1': [[5, 116]], 'SQT01_segment_2': [[4, 105]], 'SQT01_segment_3': [[2, 105]]}
# Best Score for: 2 319.4525450138642 best_combination:{'SQT01_segment_1': [[5, 116]], 'SQT01_segment_2': [[4, 105]], 'SQT01_segment_3': [[2, 105]]}
# Best Score for: 1 319.4525450138642 best_combination:{'SQT01_segment_1': [[5, 116]], 'SQT01_segment_2': [[4, 105]], 'SQT01_segment_3': [[2, 105]]}
# Best Score for: 0 315.0823177925097 best_combination:{'SQT01_segment_1': [[0, 116]], 'SQT01_segment_2': [[0, 105]], 'SQT01_segment_3': [[0, 105]]}
# [[  0 116]] SQT01_segment_1
# [[  0 105]] SQT01_segment_2
# [[  0 105]] SQT01_segment_3
# 14it [00:06,  3.14it/s]
# Evaluating Id: 14 Name: 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
#  Data:dict_keys(['dof_names', 'SQT01_segment_2', 'SQT01_segment_3'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 2.1166666700000007 13.21666667 11.1
# Subject:0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45 Trial Index:SQT01_segment_2 Length: 2.1166666700000007 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 4.116666670000001 15.48333333 13.48333333
# Subject:0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45 Trial Index:SQT01_segment_3 Length: 2.0 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_2
#   Time series: (128, 16)
# distance between valleys=6
# Max allowed valley height=19.944955401282048 allowed_height_difference_threshold=0.15
# Valleys [  2 124] Meta data:  {'peak_heights': array([-0.42706187,  0.53747781])}
# Finding valleys in For 1:SQT01_segment_3
#   Time series: (121, 16)
# distance between valleys=6
# Max allowed valley height=19.963965443890448 allowed_height_difference_threshold=0.15
# Valleys [  1 117] Meta data:  {'peak_heights': array([-0.65537335,  0.67648471])}
# Start-Stop Candidates for SQT01_segment_3 [  0   2 124 127]
# Start-Stop Candidates for SQT01_segment_3 [  0   1 117 120]
# Testing segments [[0, 124]] RMS Sequence: 986.0374398230638 RMS Threshold: 739.5280798672978
# [1023.3959666259149]
# Testing segments [[0, 127]] RMS Sequence: 986.0374398230638 RMS Threshold: 739.5280798672978
# [1023.3962040198775]
# Testing segments [[2, 124]] RMS Sequence: 986.0374398230638 RMS Threshold: 739.5280798672978
# [1023.3956486722233]
# Testing segments [[2, 127]] RMS Sequence: 986.0374398230638 RMS Threshold: 739.5280798672978
# [1023.3958860662597]
# Testing segments [[0, 117]] RMS Sequence: 986.0374398230638 RMS Threshold: 739.5280798672978
# [986.0360986642586]
# Testing segments [[0, 120]] RMS Sequence: 986.0374398230638 RMS Threshold: 739.5280798672978
# [986.036450522173]
# Testing segments [[1, 117]] RMS Sequence: 986.0374398230638 RMS Threshold: 739.5280798672978
# [986.0358604619233]
# Testing segments [[1, 120]] RMS Sequence: 986.0374398230638 RMS Threshold: 739.5280798672978
# [986.0362123199227]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_2': [[0, 124]], 'SQT01_segment_3': [[0, 117]]}
# Computing combination score:{'SQT01_segment_2': [[0, 124]], 'SQT01_segment_3': [[0, 120]]}
# Computing combination score:{'SQT01_segment_2': [[0, 124]], 'SQT01_segment_3': [[1, 117]]}
# Computing combination score:{'SQT01_segment_2': [[0, 124]], 'SQT01_segment_3': [[1, 120]]}
# Best Score for: 1 145.63679960241402 best_combination:{'SQT01_segment_2': [[0, 124]], 'SQT01_segment_3': [[0, 117]]}
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 117]], 'SQT01_segment_2': [[0, 127]]}
# Computing combination score:{'SQT01_segment_2': [[0, 127]], 'SQT01_segment_3': [[0, 120]]}
# Computing combination score:{'SQT01_segment_2': [[0, 127]], 'SQT01_segment_3': [[1, 117]]}
# Computing combination score:{'SQT01_segment_2': [[0, 127]], 'SQT01_segment_3': [[1, 120]]}
# Best Score for: 1 65.27577006683288 best_combination:{'SQT01_segment_3': [[0, 117]], 'SQT01_segment_2': [[0, 127]]}
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 117]], 'SQT01_segment_2': [[2, 124]]}
# Computing combination score:{'SQT01_segment_2': [[2, 124]], 'SQT01_segment_3': [[0, 120]]}
# Computing combination score:{'SQT01_segment_2': [[2, 124]], 'SQT01_segment_3': [[1, 117]]}
# Computing combination score:{'SQT01_segment_2': [[2, 124]], 'SQT01_segment_3': [[1, 120]]}
# Best Score for: 1 136.9570242999272 best_combination:{'SQT01_segment_2': [[2, 124]], 'SQT01_segment_3': [[1, 117]]}
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 117]], 'SQT01_segment_2': [[2, 127]]}
# Computing combination score:{'SQT01_segment_2': [[2, 127]], 'SQT01_segment_3': [[0, 120]]}
# Computing combination score:{'SQT01_segment_2': [[2, 127]], 'SQT01_segment_3': [[1, 117]]}
# Computing combination score:{'SQT01_segment_2': [[2, 127]], 'SQT01_segment_3': [[1, 120]]}
# Best Score for: 1 99.41904675716671 best_combination:{'SQT01_segment_2': [[2, 127]], 'SQT01_segment_3': [[1, 117]]}
# Best Score for: 0 65.27577006683288 best_combination:{'SQT01_segment_3': [[0, 117]], 'SQT01_segment_2': [[0, 127]]}
# [[  0 127]] SQT01_segment_2
# [[  0 117]] SQT01_segment_3
# 15it [00:07,  3.23it/s]
# Evaluating Id: 15 Name: 2345d831-6038-412e-84a9-971bc04da597
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 2.28333333 3.78333333 1.5
# Subject:2345d831-6038-412e-84a9-971bc04da597 Trial Index:SQT01_segment_1 Length: 2.28333333 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 4.166666660000001 5.68333333 3.8
# Subject:2345d831-6038-412e-84a9-971bc04da597 Trial Index:SQT01_segment_2 Length: 1.8833333300000001 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_1
#   Time series: (138, 16)
# distance between valleys=6
# Max allowed valley height=18.812983969319276 allowed_height_difference_threshold=0.15
# Valleys [133] Meta data:  {'peak_heights': array([-3.22939606])}
# Finding valleys in For 1:SQT01_segment_2
#   Time series: (114, 16)
# distance between valleys=6
# Max allowed valley height=19.384237544319998 allowed_height_difference_threshold=0.15
# Valleys [] Meta data:  {'peak_heights': array([], dtype=float64)}
# Start-Stop Candidates for SQT01_segment_2 [  0 133 137]
# Start-Stop Candidates for SQT01_segment_2 [  0 113]
# Testing segments [[0, 133]] RMS Sequence: 696.2798268089831 RMS Threshold: 522.2098701067373
# [696.605678112047]
# Testing segments [[0, 137]] RMS Sequence: 696.2798268089831 RMS Threshold: 522.2098701067373
# [696.6358382943065]
# Testing segments [[0, 113]] RMS Sequence: 696.2798268089831 RMS Threshold: 522.2098701067373
# [696.2720964475697]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_1': [[0, 133]], 'SQT01_segment_2': [[0, 113]]}
# Best Score for: 1 496.33737855708154 best_combination:{'SQT01_segment_1': [[0, 133]], 'SQT01_segment_2': [[0, 113]]}
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_2': [[0, 113]], 'SQT01_segment_1': [[0, 137]]}
# Best Score for: 1 338.9492513857935 best_combination:{'SQT01_segment_2': [[0, 113]], 'SQT01_segment_1': [[0, 137]]}
# Best Score for: 0 338.9492513857935 best_combination:{'SQT01_segment_2': [[0, 113]], 'SQT01_segment_1': [[0, 137]]}
# [[  0 137]] SQT01_segment_1
# [[  0 113]] SQT01_segment_2
# 16it [00:07,  3.25it/s]
# Evaluating Id: 16 Name: 0a959024-3371-478a-96da-bf17b1da15a9
# Subject not found in data:0a959024-3371-478a-96da-bf17b1da15a9
# Evaluating Id: 17 Name: ef656fe8-27e7-428a-84a9-deb868da053d
# Subject not found in data:ef656fe8-27e7-428a-84a9-deb868da053d
# Evaluating Id: 18 Name: c08f1d89-c843-4878-8406-b6f9798a558e
#  Data:dict_keys(['dof_names', 'SQT01_segment_2', 'SQT01_segment_3'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 1.9333333300000008 8.48333333 6.55
# Subject:c08f1d89-c843-4878-8406-b6f9798a558e Trial Index:SQT01_segment_2 Length: 1.9333333300000008 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 3.766666660000001 10.4 8.56666667
# Subject:c08f1d89-c843-4878-8406-b6f9798a558e Trial Index:SQT01_segment_3 Length: 1.8333333300000003 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_2
#   Time series: (117, 16)
# distance between valleys=6
# Max allowed valley height=15.637878956611399 allowed_height_difference_threshold=0.15
# Valleys [108] Meta data:  {'peak_heights': array([0.00607765])}
# Finding valleys in For 1:SQT01_segment_3
#   Time series: (111, 16)
# distance between valleys=6
# Max allowed valley height=15.855982447676173 allowed_height_difference_threshold=0.15
# Valleys [  5 106] Meta data:  {'peak_heights': array([-0.82413214,  0.16757413])}
# Start-Stop Candidates for SQT01_segment_3 [  0 108 116]
# Start-Stop Candidates for SQT01_segment_3 [  0   5 106 110]
# Testing segments [[0, 108]] RMS Sequence: 698.3284857721399 RMS Threshold: 523.7463643291048
# [695.0074553042163]
# Testing segments [[0, 116]] RMS Sequence: 698.3284857721399 RMS Threshold: 523.7463643291048
# [695.0077944487837]
# Testing segments [[0, 106]] RMS Sequence: 698.3284857721399 RMS Threshold: 523.7463643291048
# [698.3270308189242]
# Testing segments [[0, 110]] RMS Sequence: 698.3284857721399 RMS Threshold: 523.7463643291048
# [698.3274396585182]
# Testing segments [[5, 106]] RMS Sequence: 698.3284857721399 RMS Threshold: 523.7463643291048
# [698.3244551500686]
# Testing segments [[5, 110]] RMS Sequence: 698.3284857721399 RMS Threshold: 523.7463643291048
# [698.3248639911706]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_2': [[0, 108]], 'SQT01_segment_3': [[0, 106]]}
# Computing combination score:{'SQT01_segment_2': [[0, 108]], 'SQT01_segment_3': [[0, 110]]}
# Computing combination score:{'SQT01_segment_2': [[0, 108]], 'SQT01_segment_3': [[5, 106]]}
# Computing combination score:{'SQT01_segment_2': [[0, 108]], 'SQT01_segment_3': [[5, 110]]}
# Best Score for: 1 104.4683168872868 best_combination:{'SQT01_segment_2': [[0, 108]], 'SQT01_segment_3': [[0, 106]]}
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 106]], 'SQT01_segment_2': [[0, 116]]}
# Computing combination score:{'SQT01_segment_2': [[0, 116]], 'SQT01_segment_3': [[0, 110]]}
# Computing combination score:{'SQT01_segment_2': [[0, 116]], 'SQT01_segment_3': [[5, 106]]}
# Computing combination score:{'SQT01_segment_2': [[0, 116]], 'SQT01_segment_3': [[5, 110]]}
# Best Score for: 1 276.6690860986651 best_combination:{'SQT01_segment_2': [[0, 116]], 'SQT01_segment_3': [[0, 110]]}
# Best Score for: 0 104.4683168872868 best_combination:{'SQT01_segment_2': [[0, 108]], 'SQT01_segment_3': [[0, 106]]}
# [[  0 108]] SQT01_segment_2
# [[  0 106]] SQT01_segment_3
# 19it [00:07,  5.21it/s]
# Evaluating Id: 19 Name: d2020b0e-6d41-4759-87f0-5c158f6ab86a
# Subject not found in data:d2020b0e-6d41-4759-87f0-5c158f6ab86a
# Evaluating Id: 20 Name: 8dc21218-8338-4fd4-8164-f6f122dc33d9
#  Data:dict_keys(['dof_names', 'SQT01_segment_2', 'SQT01_segment_3'])
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 1.81666667 5.96666667 4.15
# Subject:8dc21218-8338-4fd4-8164-f6f122dc33d9 Trial Index:SQT01_segment_2 Length: 1.81666667 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate'])
# 3.6500000000000004 7.88333333 6.05
# Subject:8dc21218-8338-4fd4-8164-f6f122dc33d9 Trial Index:SQT01_segment_3 Length: 1.8333333300000003 Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# Finding valleys in For 0:SQT01_segment_2
#   Time series: (110, 16)
# distance between valleys=6
# Max allowed valley height=15.394222901622326 allowed_height_difference_threshold=0.15
# Valleys [107] Meta data:  {'peak_heights': array([0.1502866])}
# Finding valleys in For 1:SQT01_segment_3
#   Time series: (111, 16)
# distance between valleys=6
# Max allowed valley height=16.735645502210378 allowed_height_difference_threshold=0.15
# Valleys [7] Meta data:  {'peak_heights': array([-1.1780211])}
# Start-Stop Candidates for SQT01_segment_3 [  0 107 109]
# Start-Stop Candidates for SQT01_segment_3 [  0   7 110]
# Testing segments [[0, 107]] RMS Sequence: 667.54288605086 RMS Threshold: 500.657164538145
# [648.1699943695432]
# Testing segments [[0, 109]] RMS Sequence: 667.54288605086 RMS Threshold: 500.657164538145
# [648.1700118039714]
# Testing segments [[0, 110]] RMS Sequence: 667.54288605086 RMS Threshold: 500.657164538145
# [667.5416971911283]
# Testing segments [[7, 110]] RMS Sequence: 667.54288605086 RMS Threshold: 500.657164538145
# [667.5349343759399]
# 0 combinations:<class 'itertools.combinations'>
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_2': [[0, 107]], 'SQT01_segment_3': [[0, 110]]}
# Computing combination score:{'SQT01_segment_2': [[0, 107]], 'SQT01_segment_3': [[7, 110]]}
# Best Score for: 1 166.4410946779177 best_combination:{'SQT01_segment_2': [[0, 107]], 'SQT01_segment_3': [[0, 110]]}
# 1 combinations:<class 'itertools.combinations'>
# Computing combination score:{'SQT01_segment_3': [[0, 110]], 'SQT01_segment_2': [[0, 109]]}
# Computing combination score:{'SQT01_segment_2': [[0, 109]], 'SQT01_segment_3': [[7, 110]]}
# Best Score for: 1 258.51701296679886 best_combination:{'SQT01_segment_2': [[0, 109]], 'SQT01_segment_3': [[7, 110]]}
# Best Score for: 0 166.4410946779177 best_combination:{'SQT01_segment_2': [[0, 107]], 'SQT01_segment_3': [[0, 110]]}
# [[  0 107]] SQT01_segment_2
# [[  0 110]] SQT01_segment_3
# 21it [00:08,  2.58it/s]

# %%
# Merge trials across distributions for trials 
def plot_simulation_data(headers,plot_data,title_text="Plot Data",visualize=True,data_type='kinematics',num_cols=3): 
    
    assert plot_data.shape[-1] == 101, "Length of data should be 101"
    assert len(headers) == plot_data.shape[0], "Length of headers should match headers length"
    assert num_cols > 0, "Number of columns should be greater than 0"
    
    
    num_rows = int(math.ceil(len(headers)/3))
    print(data_type)
    if data_type == 'kinematics' or data_type == 'kinetics':
        fig = make_subplots(rows=num_rows, cols=num_cols, subplot_titles=[plot_names_mapping[header] for header in headers]) 
    elif  'muscle_activations' in data_type:
        fig = make_subplots(rows=num_rows, cols=num_cols, subplot_titles=[plot_muscle_activations_mapping[header] for header in headers])
    else: 
        raise ValueError("Invalid data type. Should be either kinematics or kinetics or muscle_activations")
    
    
    # Colors for left and right sides
    colors = {'left': 'blue', 'right': 'red'}

    # Create each subplot
    for i, header in enumerate(headers):
        row = i // num_cols + 1
        col = i % num_cols + 1

        if 'muscle_activations' in data_type:
            title = plot_muscle_activations_mapping[header]
        elif data_type == 'kinematics' or data_type == 'kinetics':
            title = plot_names_mapping[header]
        else:
            raise ValueError("Invalid data type. Should be either kinematics or kinetics or muscle_activations")


        # Plot every kinematics data
        x = np.linspace(0,1,num=plot_data[i].shape[-1])
        for j in range(plot_data[i].shape[0]):
            fig.add_trace(go.Scatter(x=x, y=plot_data[i,j], name=f'{title}',showlegend=False), row=row, col=col)
    
        # Update y-axis label
        if data_type == 'kinematics':
            fig.update_yaxes(title_text='deg', title_standoff=10, row=row, col=col)
        elif data_type == 'kinetics':
            fig.update_yaxes(title_text='Nm', row=row, col=col)
        else:
            fig.update_yaxes(title_text='0-1', row=row, col=col)
            
        # fig.update_yaxes(title_text='deg', row=row, col=col)

    # Update x-axis label for the bottom row
    for col in range(1, num_rows+1):
        for row in range(1,num_cols+1):
            fig.update_xaxes(title_text='% SQT Cycle (Seconds)', row=row, col=col)

    # Update layout
    plot_width = 1800 if 'muscle_activations' in data_type else 1000
    fig.update_layout(height=2000, width = 1000,
                        showlegend=False,  title_x=0.5,
                        title_text=title_text,
                        font_family="Times New Roman",
                        font_color="black",
                        title_font_family="Times New Roman",
                        title_font_color="black")

    # Show the figure
    if visualize: 
        fig.show()
    
    return fig

# %% [markdown]
# # Plot indivifual sample & Store aggregate (mean, std, list ) values

# %%
import copy

# Skip following subjects for torque simulation
# skip_subjects = ["c08f1d89-c843-4878-8406-b6f9798a558e","0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45","c28e768f-6e2b-4726-8919-c05b0af61e4a","349e4383-da38-4138-8371-9a5fed63a56a", "0e10a4e3-a93f-4b4d-9519-d9287d1d74eb",]


# Skip following subjects for muscle simulation
# skip_subjects = ["c08f1d89-c843-4878-8406-b6f9798a558e", "0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45", "c28e768f-6e2b-4726-8919-c05b0af61e4a", "349e4383-da38-4138-8371-9a5fed63a56a", "3d1207bf-192b-486a-b509-d11ca90851d7",   "0e10a4e3-a93f-4b4d-9519-d9287d1d74eb", "2345d831-6038-412e-84a9-971bc04da597", ""] # Skip subject for muscle simulation  
skip_subjects = []
num_segments = 1

# mcs_sessions = ["349e4383-da38-4138-8371-9a5fed63a56a","015b7571-9f0b-4db4-a854-68e57640640d","c613945f-1570-4011-93a4-8c8c6408e2cf","dfda5c67-a512-4ca2-a4b3-6a7e22599732","7562e3c0-dea8-46f8-bc8b-ed9d0f002a77","275561c0-5d50-4675-9df1-733390cd572f","0e10a4e3-a93f-4b4d-9519-d9287d1d74eb","a5e5d4cd-524c-4905-af85-99678e1239c8","dd215900-9827-4ae6-a07d-543b8648b1da","3d1207bf-192b-486a-b509-d11ca90851d7","c28e768f-6e2b-4726-8919-c05b0af61e4a","fb6e8f87-a1cc-48b4-8217-4e8b160602bf","e6b10bbf-4e00-4ac0-aade-68bc1447de3e","d66330dc-7884-4915-9dbb-0520932294c4","0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45","2345d831-6038-412e-84a9-971bc04da597","0a959024-3371-478a-96da-bf17b1da15a9","ef656fe8-27e7-428a-84a9-deb868da053d","c08f1d89-c843-4878-8406-b6f9798a558e","d2020b0e-6d41-4759-87f0-5c158f6ab86a","8dc21218-8338-4fd4-8164-f6f122dc33d9"]

# mcs_scores = [4,4,2,3,2,4,3,3,2,3,0,3,4,2,2,3,4,4,3,3,3]
# mcs_scores = dict(zip(mcs_sessions,mcs_scores))

# PPE_Subjects = ["PPE09182201","PPE09182202","PPE09182203","PPE09182204","PPE09182205","PPE09182206","PPE09182207","PPE09182208","PPE09182209","PPE091822010","PPE09182211","PPE09182212","PPE09182213","PPE09182214","PPE09182215","PPE09182216","PPE09182217","PPE09182218","PPE09182219","PPE09182220","PPE09182221"]
# PPE_Subjects = dict(zip(mcs_sessions,PPE_Subjects))

############### STORE Manual segmentation results here: 
# manually_segment_subjects_list = [("3d1207bf-192b-486a-b509-d11ca90851d7","SQT01_segment_1"),
#                                   ("3d1207bf-192b-486a-b509-d11ca90851d7","SQT01_segment_2"),
#                                   ("3d1207bf-192b-486a-b509-d11ca90851d7","SQT01_segment_3"), 
                                  
#                                   ("2345d831-6038-412e-84a9-971bc04da597","SQT01_segment_1")]

manual_segments = {} 
# for subject_name,trial_name in manually_segment_subjects_list: 
#     if subject_name not in manual_segments: 
#         manual_segments[subject_name] = {}
#         continue 
    
#     if trial_name not in manual_segments[subject_name]:
#         manual_segments[subject_name][trial_name] = np.zeros((1,2)) # If not segment found, skip the trial
#         continue 
    
#     if 'segments' not in subjects[subject_name][trial_name]: 
#         continue 
    
#     manual_segments[subject_name][trial_name] = copy.deepcopy(subjects[subject_name][trial_name]['segments'])

    
# # Check and update the first set of keys
# if "3d1207bf-192b-486a-b509-d11ca90851d7" in manual_segments:
#     if "SQT01_segment_3" in manual_segments["3d1207bf-192b-486a-b509-d11ca90851d7"]:
#         manual_segments["3d1207bf-192b-486a-b509-d11ca90851d7"]["SQT01_segment_3"][0][0] += 15
#         manual_segments["3d1207bf-192b-486a-b509-d11ca90851d7"]["SQT01_segment_3"][0][1] += 15

#     # if "SQT01_segment_1" in manual_segments["3d1207bf-192b-486a-b509-d11ca90851d7"]:
#     #     manual_segments["3d1207bf-192b-486a-b509-d11ca90851d7"]["SQT01_segment_1"][0][0] += 40
#     #     manual_segments["3d1207bf-192b-486a-b509-d11ca90851d7"]["SQT01_segment_1"][0][1] += 40

# # Check and update the second set of keys
# if "2345d831-6038-412e-84a9-971bc04da597" in manual_segments:
#     if "SQT01_segment_1" in manual_segments["2345d831-6038-412e-84a9-971bc04da597"]:
#         manual_segments["2345d831-6038-412e-84a9-971bc04da597"]["SQT01_segment_1"][0][0] += 40 
        




##########################################################


os.makedirs("pdfs",exist_ok=True)

aggregate_data = {}
mcs_aggregate_data = {2:{}, 3:{}, 4:{}, 0:{}, -1:{}}
for plotting_variable in ['kinematics','kinetics']:
    aggregate_data[plotting_variable] = {}
    aggregate_data[plotting_variable]['mean'] = np.zeros((len(plot_names_mapping),101))
    aggregate_data[plotting_variable]['std'] = np.zeros((len(plot_names_mapping),101))


######## For muscle activations  #####################
for page_index, page_dict in enumerate(plot_muscle_activations_mapping_pages):
    aggregate_data[f'muscle_activations-{page_index}'] = {}
    aggregate_data[f'muscle_activations-{page_index}']['mean'] = np.zeros((len(page_dict),101))
    aggregate_data[f'muscle_activations-{page_index}']['std'] = np.zeros((len(page_dict),101))


    aggregate_data[f'muscle_activations-surrogate-{page_index}'] = {}
    aggregate_data[f'muscle_activations-surrogate-{page_index}']['mean'] = np.zeros((len(page_dict),101))
    aggregate_data[f'muscle_activations-surrogate-{page_index}']['std'] = np.zeros((len(page_dict),101))



total_trials = 0

for subject_ind, subject_name in tqdm.tqdm(enumerate(subjects)):

    # Check if all the details that have to be plotted exist    
    if subject_name in skip_subjects: 
        continue 
    
    if len(subjects[subject_name]) <= 1:  # If dict is empty skip.
        print(f"Subject is empty:{subjects[subject_name]}")    
        continue
    
    print(f" Data:{subjects[subject_name].keys()}")
    
    plot_headers = None
    plot_data = {}

    for trial_name in subjects[subject_name]: 
        if trial_name == 'dof_names': continue
        if trial_name == 'seconds_per_frame': continue  
        
        if len(subjects[subject_name][trial_name]) <= 1:  # If dict is empty skip.
            print(f"Trial is empty:{subjects[subject_name][trial_name]}") 
            continue 
        print(subjects[subject_name][trial_name].keys())
    
        trial_length = subjects[subject_name][trial_name]['kinematics']['time'].iloc[-1] - subjects[subject_name][trial_name]['kinematics']['time'].iloc[0]
        if trial_length < 1: continue # Can't perform squat in less tha a second. 
        
 
        plot_headers, plot_data_trial = get_plotting_data(subjects[subject_name],trial_name)
        
    
        # Temporal Segmentation (using knee angles kinematics since it gave the most reasonable results) 
        try: 
            if subject_name in manual_segments and trial_name in manual_segments[subject_name]:
                segments = manual_segments[subject_name][trial_name]
            else: 
                segments = subjects[subject_name][trial_name]['segments']            
        except Exception as e: 
            print(f"Error computing segments using temporal segmetnation",e) 
            continue
        
        
        segment_time = sum([  segments[i][1] - segments[i][0] for i in range(len(segments))])*subjects[subject_name]['seconds_per_frame']
        
        print(f"    Subject:{subject_name} Trial Index:{trial_name} Length: {trial_length} Segment Length:{segment_time}  {segments} Headers:{plot_headers}")
        
        for plotting_variable in plot_data_trial:
            assert len(plot_data_trial[plotting_variable].shape) == 2, "Data should be 2D"

            time_normalized_series = [time_normalization(plot_data_trial[plotting_variable][segment[0]:segment[1]]) for segment in segments if segment[1] > segment[0] ] 
            
            if plotting_variable not in plot_data:
                plot_data[plotting_variable] = []
            plot_data[plotting_variable].extend(time_normalized_series)

    if len(plot_data) == 0: # Tracks are empty  
        continue
    
    for plotting_variable in plot_data: 
        plot_data[plotting_variable] = np.array(plot_data[plotting_variable]).transpose((2,0,1))

        print(subject_name)

        fig_title = f"{plotting_variable} for Subject:{PPE_Subjects[subject_name]} MCS:{mcs_scores[subject_name]}"
        if plotting_variable == 'kinematics' or plotting_variable == 'kinetics':
            fig = plot_simulation_data(plot_headers, plot_data[plotting_variable], fig_title, visualize=False , data_type=plotting_variable)
        elif 'muscle_activations' in plotting_variable:
            mc_page_index = int(plotting_variable.split('-')[-1])
            plot_mc_headers = plot_muscle_activations_mapping_pages[mc_page_index]
            fig = plot_simulation_data(plot_mc_headers, plot_data[plotting_variable], fig_title, visualize=False , data_type=plotting_variable,num_cols = 4)
        else: 
            raise ValueError(f"Unknown plotting variable:{plotting_variable}")        
        plotly.io.write_image(fig, f'pdfs/{PPE_Subjects[subject_name]}_{plotting_variable}.pdf', format='pdf')


        if not np.isnan(plot_data[plotting_variable]).any(): 
            aggregate_data[plotting_variable]['mean'] += plot_data[plotting_variable].sum(axis=1)
            aggregate_data[plotting_variable]['std'] += (plot_data[plotting_variable]**2).sum(axis=1)
            
            mcs_score = mcs_scores[subject_name]

            if plotting_variable not in mcs_aggregate_data[mcs_score]: 
                mcs_aggregate_data[mcs_score][plotting_variable] = {} 
                
                if 'muscle_activations' in plotting_variable:
                    mc_page_index = int(plotting_variable.split('-')[-1])
                    mcs_aggregate_data[mcs_score][plotting_variable]['mean'] = np.zeros((len(plot_muscle_activations_mapping_pages[mc_page_index]),101))
                    mcs_aggregate_data[mcs_score][plotting_variable]['std'] = np.zeros((len(plot_muscle_activations_mapping_pages[mc_page_index]),101))
                    mcs_aggregate_data[mcs_score][plotting_variable]['list'] = np.zeros((0,len(plot_muscle_activations_mapping_pages[mc_page_index]),101))
                elif plotting_variable == 'kinematics' or plotting_variable == 'kinetics': 
                    mcs_aggregate_data[mcs_score][plotting_variable]['mean'] = np.zeros((len(plot_names_mapping),101))
                    mcs_aggregate_data[mcs_score][plotting_variable]['std'] = np.zeros((len(plot_names_mapping),101))
                    mcs_aggregate_data[mcs_score][plotting_variable]['list'] = np.zeros((0,len(plot_names_mapping),101))

                else: 
                    raise ValueError(f"Unknown plotting variable:{plotting_variable}")

                mcs_aggregate_data[mcs_score][plotting_variable]['ppe_names'] = []
                mcs_aggregate_data[mcs_score][plotting_variable]['ppe_trial'] = []
                mcs_aggregate_data[mcs_score][plotting_variable]['total_trials'] = 0
            
            mcs_aggregate_data[mcs_score][plotting_variable]['mean'] += plot_data[plotting_variable].sum(axis=1)
            mcs_aggregate_data[mcs_score][plotting_variable]['std'] += (plot_data[plotting_variable]**2).sum(axis=1)

            mcs_aggregate_data[mcs_score][plotting_variable]['list'] = np.concatenate([ mcs_aggregate_data[mcs_score][plotting_variable]['list'],
                                                                                       np.transpose(plot_data[plotting_variable], (1,0,2)   ) ])
            
            mcs_aggregate_data[mcs_score][plotting_variable]['ppe_names'].extend([PPE_Subjects[subject_name]]*plot_data[plotting_variable].shape[1])
            # mcs_aggregate_data[mcs_score][plotting_variable]['ppe_trial'].extend([trial_index]*plot_data[plotting_variable].shape[1])
            mcs_aggregate_data[mcs_score][plotting_variable]['total_trials'] += plot_data[plotting_variable].shape[1]
            
            
    total_trials += plot_data[plotting_variable].shape[1]
        



for k in aggregate_data:
    aggregate_data[k]['mean'] /= total_trials
    aggregate_data[k]['std'] = np.sqrt(aggregate_data[k]['std']/total_trials - aggregate_data[k]['mean']**2)

    # break

for mcs_score in mcs_aggregate_data:
    for plotting_variable in mcs_aggregate_data[mcs_score]: 
        mcs_aggregate_data[mcs_score][plotting_variable]['mean'] /= mcs_aggregate_data[mcs_score][plotting_variable]['total_trials']
        mcs_aggregate_data[mcs_score][plotting_variable]['std'] = np.sqrt(mcs_aggregate_data[mcs_score][plotting_variable]['std']/mcs_aggregate_data[mcs_score][plotting_variable]['total_trials'] - mcs_aggregate_data[mcs_score][plotting_variable]['mean']**2)
# Out:
# 0it [00:00, ?it/s]
#  Data:dict_keys(['dof_names', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:8dc21218-8338-4fd4-8164-f6f122dc33d9 Trial Index:SQT01_segment_2 Length: 1.81666667 Segment Length:1.7671945701357465  [[0, 107]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:8dc21218-8338-4fd4-8164-f6f122dc33d9 Trial Index:SQT01_segment_3 Length: 1.8333333300000003 Segment Length:1.8167420814479638  [[0, 110]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# kinematics
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# kinetics
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# muscle_activations-0
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# muscle_activations-surrogate-0
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# muscle_activations-1
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# muscle_activations-surrogate-1
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# muscle_activations-2
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# muscle_activations-surrogate-2
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# muscle_activations-3
# 8dc21218-8338-4fd4-8164-f6f122dc33d9
# muscle_activations-surrogate-3
# 1it [00:06,  6.48s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:c08f1d89-c843-4878-8406-b6f9798a558e Trial Index:SQT01_segment_2 Length: 1.9333333300000008 Segment Length:1.7842105231578955  [[0, 108]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:c08f1d89-c843-4878-8406-b6f9798a558e Trial Index:SQT01_segment_3 Length: 1.8333333300000003 Segment Length:1.7511695875438604  [[0, 106]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# c08f1d89-c843-4878-8406-b6f9798a558e
# kinematics
# c08f1d89-c843-4878-8406-b6f9798a558e
# kinetics
# c08f1d89-c843-4878-8406-b6f9798a558e
# muscle_activations-0
# c08f1d89-c843-4878-8406-b6f9798a558e
# muscle_activations-surrogate-0
# c08f1d89-c843-4878-8406-b6f9798a558e
# muscle_activations-1
# c08f1d89-c843-4878-8406-b6f9798a558e
# muscle_activations-surrogate-1
# c08f1d89-c843-4878-8406-b6f9798a558e
# muscle_activations-2
# c08f1d89-c843-4878-8406-b6f9798a558e
# muscle_activations-surrogate-2
# c08f1d89-c843-4878-8406-b6f9798a558e
# muscle_activations-3
# c08f1d89-c843-4878-8406-b6f9798a558e
# muscle_activations-surrogate-3
# 2it [00:13,  6.74s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:2345d831-6038-412e-84a9-971bc04da597 Trial Index:SQT01_segment_1 Length: 2.28333333 Segment Length:2.265211636587302  [[0, 137]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:2345d831-6038-412e-84a9-971bc04da597 Trial Index:SQT01_segment_2 Length: 1.8833333300000001 Segment Length:1.8683862403968259  [[0, 113]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 2345d831-6038-412e-84a9-971bc04da597
# kinematics
# 2345d831-6038-412e-84a9-971bc04da597
# kinetics
# 2345d831-6038-412e-84a9-971bc04da597
# muscle_activations-0
# 2345d831-6038-412e-84a9-971bc04da597
# muscle_activations-surrogate-0
# 2345d831-6038-412e-84a9-971bc04da597
# muscle_activations-1
# 2345d831-6038-412e-84a9-971bc04da597
# muscle_activations-surrogate-1
# 2345d831-6038-412e-84a9-971bc04da597
# muscle_activations-2
# 2345d831-6038-412e-84a9-971bc04da597
# muscle_activations-surrogate-2
# 2345d831-6038-412e-84a9-971bc04da597
# muscle_activations-3
# 2345d831-6038-412e-84a9-971bc04da597
# muscle_activations-surrogate-3
# 3it [00:19,  6.63s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45 Trial Index:SQT01_segment_2 Length: 2.1166666700000007 Segment Length:2.0996653296787153  [[0, 127]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45 Trial Index:SQT01_segment_3 Length: 2.0 Segment Length:1.934337350963856  [[0, 117]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# kinematics
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# kinetics
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# muscle_activations-0
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# muscle_activations-surrogate-0
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# muscle_activations-1
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# muscle_activations-surrogate-1
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# muscle_activations-2
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# muscle_activations-surrogate-2
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# muscle_activations-3
# 0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45
# muscle_activations-surrogate-3
# 4it [00:28,  7.32s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:d66330dc-7884-4915-9dbb-0520932294c4 Trial Index:SQT01_segment_1 Length: 1.933333339999999 Segment Length:1.9157041563525825  [[0, 116]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:d66330dc-7884-4915-9dbb-0520932294c4 Trial Index:SQT01_segment_2 Length: 1.7499999999999982 Segment Length:1.7340425553191479  [[0, 105]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:d66330dc-7884-4915-9dbb-0520932294c4 Trial Index:SQT01_segment_3 Length: 1.75 Segment Length:1.7340425553191479  [[0, 105]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# d66330dc-7884-4915-9dbb-0520932294c4
# kinematics
# d66330dc-7884-4915-9dbb-0520932294c4
# kinetics
# d66330dc-7884-4915-9dbb-0520932294c4
# muscle_activations-0
# d66330dc-7884-4915-9dbb-0520932294c4
# muscle_activations-surrogate-0
# d66330dc-7884-4915-9dbb-0520932294c4
# muscle_activations-1
# d66330dc-7884-4915-9dbb-0520932294c4
# muscle_activations-surrogate-1
# d66330dc-7884-4915-9dbb-0520932294c4
# muscle_activations-2
# d66330dc-7884-4915-9dbb-0520932294c4
# muscle_activations-surrogate-2
# d66330dc-7884-4915-9dbb-0520932294c4
# muscle_activations-3
# d66330dc-7884-4915-9dbb-0520932294c4
# muscle_activations-surrogate-3
# 5it [00:35,  7.15s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:e6b10bbf-4e00-4ac0-aade-68bc1447de3e Trial Index:SQT01_segment_1 Length: 2.11666667 Segment Length:2.08359375328125  [[0, 126]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# kinematics
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# kinetics
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# muscle_activations-0
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# muscle_activations-surrogate-0
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# muscle_activations-1
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# muscle_activations-surrogate-1
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# muscle_activations-2
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# muscle_activations-surrogate-2
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# muscle_activations-3
# e6b10bbf-4e00-4ac0-aade-68bc1447de3e
# muscle_activations-surrogate-3
# 6it [00:40,  6.44s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:c28e768f-6e2b-4726-8919-c05b0af61e4a Trial Index:SQT01_segment_1 Length: 1.86666666 Segment Length:1.8488322705732485  [[0, 112]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:c28e768f-6e2b-4726-8919-c05b0af61e4a Trial Index:SQT01_segment_2 Length: 1.6666666700000006 Segment Length:1.6507430987261147  [[0, 100]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:c28e768f-6e2b-4726-8919-c05b0af61e4a Trial Index:SQT01_segment_3 Length: 1.6500000000000004 Segment Length:1.6342356677388536  [[0, 99]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# kinematics
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# kinetics
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# muscle_activations-0
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# muscle_activations-surrogate-0
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# muscle_activations-1
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# muscle_activations-surrogate-1
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# muscle_activations-2
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# muscle_activations-surrogate-2
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# muscle_activations-3
# c28e768f-6e2b-4726-8919-c05b0af61e4a
# muscle_activations-surrogate-3
# 7it [00:47,  6.66s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:3d1207bf-192b-486a-b509-d11ca90851d7 Trial Index:SQT01_segment_1 Length: 2.3499999999999996 Segment Length:2.332462686567164  [[0, 141]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:3d1207bf-192b-486a-b509-d11ca90851d7 Trial Index:SQT01_segment_2 Length: 2.35 Segment Length:2.332462686567164  [[0, 141]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:3d1207bf-192b-486a-b509-d11ca90851d7 Trial Index:SQT01_segment_3 Length: 1.950000000000001 Segment Length:1.9354477611940297  [[0, 117]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 3d1207bf-192b-486a-b509-d11ca90851d7
# kinematics
# 3d1207bf-192b-486a-b509-d11ca90851d7
# kinetics
# 3d1207bf-192b-486a-b509-d11ca90851d7
# muscle_activations-0
# 3d1207bf-192b-486a-b509-d11ca90851d7
# muscle_activations-surrogate-0
# 3d1207bf-192b-486a-b509-d11ca90851d7
# muscle_activations-1
# 3d1207bf-192b-486a-b509-d11ca90851d7
# muscle_activations-surrogate-1
# 3d1207bf-192b-486a-b509-d11ca90851d7
# muscle_activations-2
# 3d1207bf-192b-486a-b509-d11ca90851d7
# muscle_activations-surrogate-2
# 3d1207bf-192b-486a-b509-d11ca90851d7
# muscle_activations-3
# 3d1207bf-192b-486a-b509-d11ca90851d7
# muscle_activations-surrogate-3
# 8it [00:53,  6.61s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:dd215900-9827-4ae6-a07d-543b8648b1da Trial Index:SQT01_segment_1 Length: 2.0999999999999996 Segment Length:2.0838874658823525  [[0, 126]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:dd215900-9827-4ae6-a07d-543b8648b1da Trial Index:SQT01_segment_2 Length: 2.1333333299999993 Segment Length:2.116965044705882  [[0, 128]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:dd215900-9827-4ae6-a07d-543b8648b1da Trial Index:SQT01_segment_3 Length: 2.2333333300000007 Segment Length:2.2161977811764704  [[0, 134]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dd215900-9827-4ae6-a07d-543b8648b1da
# kinematics
# dd215900-9827-4ae6-a07d-543b8648b1da
# kinetics
# dd215900-9827-4ae6-a07d-543b8648b1da
# muscle_activations-0
# dd215900-9827-4ae6-a07d-543b8648b1da
# muscle_activations-surrogate-0
# dd215900-9827-4ae6-a07d-543b8648b1da
# muscle_activations-1
# dd215900-9827-4ae6-a07d-543b8648b1da
# muscle_activations-surrogate-1
# dd215900-9827-4ae6-a07d-543b8648b1da
# muscle_activations-2
# dd215900-9827-4ae6-a07d-543b8648b1da
# muscle_activations-surrogate-2
# dd215900-9827-4ae6-a07d-543b8648b1da
# muscle_activations-3
# dd215900-9827-4ae6-a07d-543b8648b1da
# muscle_activations-surrogate-3
# 9it [01:01,  6.84s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:a5e5d4cd-524c-4905-af85-99678e1239c8 Trial Index:SQT01_segment_1 Length: 2.4000000000000004 Segment Length:2.382816231408115  [[0, 144]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:a5e5d4cd-524c-4905-af85-99678e1239c8 Trial Index:SQT01_segment_2 Length: 2.2833333400000004 Segment Length:2.184248212124105  [[5, 137]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:a5e5d4cd-524c-4905-af85-99678e1239c8 Trial Index:SQT01_segment_3 Length: 2.25 Segment Length:2.134606207303103  [[0, 129]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# a5e5d4cd-524c-4905-af85-99678e1239c8
# kinematics
# a5e5d4cd-524c-4905-af85-99678e1239c8
# kinetics
# a5e5d4cd-524c-4905-af85-99678e1239c8
# muscle_activations-0
# a5e5d4cd-524c-4905-af85-99678e1239c8
# muscle_activations-surrogate-0
# a5e5d4cd-524c-4905-af85-99678e1239c8
# muscle_activations-1
# a5e5d4cd-524c-4905-af85-99678e1239c8
# muscle_activations-surrogate-1
# a5e5d4cd-524c-4905-af85-99678e1239c8
# muscle_activations-2
# a5e5d4cd-524c-4905-af85-99678e1239c8
# muscle_activations-surrogate-2
# a5e5d4cd-524c-4905-af85-99678e1239c8
# muscle_activations-3
# a5e5d4cd-524c-4905-af85-99678e1239c8
# muscle_activations-surrogate-3
# 10it [01:07,  6.82s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:0e10a4e3-a93f-4b4d-9519-d9287d1d74eb Trial Index:SQT01_segment_1 Length: 3.2499999999999996 Segment Length:3.212695034085106  [[1, 195]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:0e10a4e3-a93f-4b4d-9519-d9287d1d74eb Trial Index:SQT01_segment_2 Length: 1.9833333299999998 Segment Length:1.9706737580212763  [[0, 119]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:0e10a4e3-a93f-4b4d-9519-d9287d1d74eb Trial Index:SQT01_segment_3 Length: 2.5500000000000007 Segment Length:2.450921984765957  [[0, 148]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# kinematics
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# kinetics
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# muscle_activations-0
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# muscle_activations-surrogate-0
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# muscle_activations-1
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# muscle_activations-surrogate-1
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# muscle_activations-2
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# muscle_activations-surrogate-2
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# muscle_activations-3
# 0e10a4e3-a93f-4b4d-9519-d9287d1d74eb
# muscle_activations-surrogate-3
# 11it [01:15,  7.18s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:275561c0-5d50-4675-9df1-733390cd572f Trial Index:SQT01_segment_1 Length: 2.23333333 Segment Length:2.1180406227956987  [[0, 128]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:275561c0-5d50-4675-9df1-733390cd572f Trial Index:SQT01_segment_2 Length: 2.38333334 Segment Length:2.3662485082795697  [[0, 143]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 275561c0-5d50-4675-9df1-733390cd572f
# kinematics
# 275561c0-5d50-4675-9df1-733390cd572f
# kinetics
# 275561c0-5d50-4675-9df1-733390cd572f
# muscle_activations-0
# 275561c0-5d50-4675-9df1-733390cd572f
# muscle_activations-surrogate-0
# 275561c0-5d50-4675-9df1-733390cd572f
# muscle_activations-1
# 275561c0-5d50-4675-9df1-733390cd572f
# muscle_activations-surrogate-1
# 275561c0-5d50-4675-9df1-733390cd572f
# muscle_activations-2
# 275561c0-5d50-4675-9df1-733390cd572f
# muscle_activations-surrogate-2
# 275561c0-5d50-4675-9df1-733390cd572f
# muscle_activations-3
# 275561c0-5d50-4675-9df1-733390cd572f
# muscle_activations-surrogate-3
# 12it [01:28,  8.89s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 Trial Index:SQT01_segment_1 Length: 2.3499999999999996 Segment Length:2.3006896519770113  [[0, 139]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 Trial Index:SQT01_segment_2 Length: 2.2833333299999996 Segment Length:2.1682758590574713  [[0, 131]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:7562e3c0-dea8-46f8-bc8b-ed9d0f002a77 Trial Index:SQT01_segment_3 Length: 2.566666660000001 Segment Length:2.135172410827586  [[8, 137]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# kinematics
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# kinetics
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# muscle_activations-0
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# muscle_activations-surrogate-0
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# muscle_activations-1
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# muscle_activations-surrogate-1
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# muscle_activations-2
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# muscle_activations-surrogate-2
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# muscle_activations-3
# 7562e3c0-dea8-46f8-bc8b-ed9d0f002a77
# muscle_activations-surrogate-3
# 13it [01:42, 10.49s/it]
#  Data:dict_keys(['dof_names', 'SQT01_segment_1', 'SQT01_segment_2', 'SQT01_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:015b7571-9f0b-4db4-a854-68e57640640d Trial Index:SQT01_segment_1 Length: 2.2 Segment Length:2.1171717139393937  [[0, 128]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:015b7571-9f0b-4db4-a854-68e57640640d Trial Index:SQT01_segment_2 Length: 2.16666666 Segment Length:2.150252521969697  [[0, 130]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'surrogate', 'segments'])
#     Subject:015b7571-9f0b-4db4-a854-68e57640640d Trial Index:SQT01_segment_3 Length: 2.18333333 Segment Length:2.1171717139393937  [[3, 131]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 015b7571-9f0b-4db4-a854-68e57640640d
# kinematics
# 015b7571-9f0b-4db4-a854-68e57640640d
# kinetics
# 015b7571-9f0b-4db4-a854-68e57640640d
# muscle_activations-0
# 015b7571-9f0b-4db4-a854-68e57640640d
# muscle_activations-surrogate-0
# 015b7571-9f0b-4db4-a854-68e57640640d
# muscle_activations-1
# 015b7571-9f0b-4db4-a854-68e57640640d
# muscle_activations-surrogate-1
# 015b7571-9f0b-4db4-a854-68e57640640d
# muscle_activations-2
# 015b7571-9f0b-4db4-a854-68e57640640d
# muscle_activations-surrogate-2
# 015b7571-9f0b-4db4-a854-68e57640640d
# muscle_activations-3
# 015b7571-9f0b-4db4-a854-68e57640640d
# muscle_activations-surrogate-3
# 14it [01:57, 11.65s/it]
#  Data:dict_keys(['dof_names', 'SQT01_1_segment_1', 'SQT01_1_segment_2', 'SQT01_1_segment_3', 'seconds_per_frame'])
# dict_keys(['kinetics', 'kinematics', 'segments'])
#     Subject:349e4383-da38-4138-8371-9a5fed63a56a Trial Index:SQT01_1_segment_1 Length: 2.2 Segment Length:2.183622829875931  [[0, 132]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'segments'])
#     Subject:349e4383-da38-4138-8371-9a5fed63a56a Trial Index:SQT01_1_segment_2 Length: 2.0500000000000003 Segment Length:2.001654260719603  [[2, 123]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# dict_keys(['kinetics', 'kinematics', 'segments'])
#     Subject:349e4383-da38-4138-8371-9a5fed63a56a Trial Index:SQT01_1_segment_3 Length: 2.4166666700000006 Segment Length:2.365591399032258  [[2, 145]] Headers:['lumbar_bending', 'lumbar_extension', 'lumbar_rotation', 'pelvis_list', 'pelvis_tilt', 'pelvis_rotation', 'hip_adduction_l', 'hip_flexion_l', 'hip_rotation_l', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_l', 'knee_angle_r', 'ankle_angle_l', 'ankle_angle_r']
# 349e4383-da38-4138-8371-9a5fed63a56a
# kinematics
# 349e4383-da38-4138-8371-9a5fed63a56a
# kinetics
# 349e4383-da38-4138-8371-9a5fed63a56a
# muscle_activations-0
# 349e4383-da38-4138-8371-9a5fed63a56a
# muscle_activations-surrogate-0
# 349e4383-da38-4138-8371-9a5fed63a56a
# muscle_activations-1
# 349e4383-da38-4138-8371-9a5fed63a56a
# muscle_activations-surrogate-1
# 349e4383-da38-4138-8371-9a5fed63a56a
# muscle_activations-2
# 349e4383-da38-4138-8371-9a5fed63a56a
# muscle_activations-surrogate-2
# 349e4383-da38-4138-8371-9a5fed63a56a
# muscle_activations-3
# 349e4383-da38-4138-8371-9a5fed63a56a
# muscle_activations-surrogate-3
# 15it [02:12,  8.83s/it]

# %%
mcs_scores
# Out:
# {'349e4383-da38-4138-8371-9a5fed63a56a': 4,
#  '015b7571-9f0b-4db4-a854-68e57640640d': 4,
#  'c613945f-1570-4011-93a4-8c8c6408e2cf': 2,
#  'dfda5c67-a512-4ca2-a4b3-6a7e22599732': 3,
#  '7562e3c0-dea8-46f8-bc8b-ed9d0f002a77': 2,
#  '275561c0-5d50-4675-9df1-733390cd572f': 4,
#  '0e10a4e3-a93f-4b4d-9519-d9287d1d74eb': 3,
#  'a5e5d4cd-524c-4905-af85-99678e1239c8': 3,
#  'dd215900-9827-4ae6-a07d-543b8648b1da': 2,
#  '3d1207bf-192b-486a-b509-d11ca90851d7': 3,
#  'c28e768f-6e2b-4726-8919-c05b0af61e4a': 4,
#  'fb6e8f87-a1cc-48b4-8217-4e8b160602bf': 3,
#  'e6b10bbf-4e00-4ac0-aade-68bc1447de3e': 4,
#  'd66330dc-7884-4915-9dbb-0520932294c4': 2,
#  '0d9e84e9-57a4-4534-aee2-0d0e8d1e7c45': 2,
#  '2345d831-6038-412e-84a9-971bc04da597': 3,
#  '0a959024-3371-478a-96da-bf17b1da15a9': 4,
#  'ef656fe8-27e7-428a-84a9-deb868da053d': 4,
#  'c08f1d89-c843-4878-8406-b6f9798a558e': 3,
#  'd2020b0e-6d41-4759-87f0-5c158f6ab86a': 3,
#  '8dc21218-8338-4fd4-8164-f6f122dc33d9': 3}

# %%
plot_data.keys()
# Out:
# dict_keys(['kinematics', 'kinetics', 'muscle_activations-0', 'muscle_activations-surrogate-0', 'muscle_activations-1', 'muscle_activations-surrogate-1', 'muscle_activations-2', 'muscle_activations-surrogate-2', 'muscle_activations-3', 'muscle_activations-surrogate-3'])

# %%
assert plot_headers is not None, "Something went wrong. Headers should not be None"

# %% [markdown]
# # Plot Aggregate values

# %%
from matplotlib.pyplot import plot


def plot_data_distribution(headers,plot_data_mean,plot_data_std,title_text="Plot Data",data_type="kinematics",num_cols=3,visualize=False): 
    
    # assert plot_data.shape[-1] == 101, "Length of data should be 101"
    num_rows = int(math.ceil(len(headers)/num_cols))


    if data_type == 'kinematics' or data_type == 'kinetics':
        fig = make_subplots(rows=num_rows, cols=num_cols, subplot_titles=[ plot_names_mapping[header] + ( ' moments' if data_type == 'kinetics' else '' )  for header in headers]) 
    elif  'muscle_activations' in data_type:
        fig = make_subplots(rows=num_rows, cols=num_cols, subplot_titles=[plot_muscle_activations_mapping[header] for header in headers])
    else: 
        raise ValueError("Invalid data type. Should be either kinematics or kinetics or muscle_activations")


    # Colors for left and right sides
    colors = {'left': 'blue', 'right': 'red'}

    # Create each subplot
    for i, header in enumerate(headers):
        row = i // num_cols + 1
        col = i % num_cols + 1
        
        if i >= len(headers): 
            break


        if 'muscle_activations' in data_type:
            title = plot_muscle_activations_mapping[header]
        elif data_type == 'kinematics' or data_type == 'kinetics':
            title = plot_names_mapping[header]
        else:
            raise ValueError("Invalid data type. Should be either kinematics or kinetics or muscle_activations")

        # Plot every kinematics data
        x = np.linspace(0,1,num=plot_data_mean[i].shape[-1])

    
        fig.add_trace(go.Scatter(x=x, y=plot_data_mean[i], showlegend=False, name=f'{title}'), row=row, col=col)
        fig.add_trace(go.Scatter(x=list(x) + list(x)[::-1], 
                                    y=list(plot_data_mean[i] + np.array(plot_data_std[i])) + list(np.array(plot_data_mean[i]) - np.array(plot_data_std[i]))[::-1] ,
                                        mode='lines', line=dict(width=0), name=f'{title} Bounds', showlegend=False, fill='toself',hoverinfo="skip",),
        row=row, col=col)

        # Update y-axis label
        if data_type == 'kinematics':
            fig.update_yaxes(title_text='deg', row=row, col=col)
        elif data_type == 'kinetics':
            fig.update_yaxes(title_text='Nm', row=row, col=col)
        elif 'muscle_activations' in data_type: 
            fig.update_yaxes(title_text='0-1', row=row, col=col)

        fig.update_xaxes(title_text='% SQT Cycle (Seconds)', row=row, col=col)

    

    # Update layout
    # plot_height = 1800 if 'muscle_activations' in data_type else 1000
    fig.update_layout(height=2000, width=1000,
                        showlegend=False,  title_x=0.5,
                        title_text=title_text,
                        font_family="Times New Roman",
                        font_color="black",
                        title_font_family="Times New Roman",
                        title_font_color="black")

    # Show the figure
    if visualize:
        fig.show()
    
    return fig

for k in aggregate_data:
    if k == 'kinematics' or k == 'kinetics':
        fig = plot_data_distribution(plot_headers, aggregate_data[k]['mean'],aggregate_data[k]['std'], f"Aggregate {k} Data",data_type=k)
        plotly.io.write_image(fig, f'pdfs/all_subject_{k}.pdf', format='pdf')
    
    elif 'muscle_activations' in k:
        mc_page_index = int(k.split('-')[-1])
        fig = plot_data_distribution(plot_muscle_activations_mapping_pages[mc_page_index], aggregate_data[k]['mean'],aggregate_data[k]['std'], f"Aggregate {k} Data",data_type=k)
        plotly.io.write_image(fig, f'pdfs/all_subject_{k}.pdf', format='pdf')
    else: 
        raise ValueError(f"Unknown plotting variable:{k}")

# %%
# Plot Per MCS data

def plot_mcs_distribution(headers,mcs_aggregate_data,title_text="Plot Data",data_type="kinematics", num_cols=3): 
    
    # assert plot_data.shape[-1] == 101, "Length of data should be 101"
    num_rows = int(math.ceil(len(headers)/num_cols))

    # Create 4x4 subplots (we'll only use 14 of them)
    if data_type == 'kinematics' or data_type == 'kinetics':
        fig = make_subplots(rows=num_rows, cols=num_cols, subplot_titles=[plot_names_mapping[header] + ( ' moments' if data_type == 'kinetics' else '' ) for header in headers])
    elif  'muscle_activations' in data_type:
        fig = make_subplots(rows=num_rows, cols=num_cols, subplot_titles=[plot_muscle_activations_mapping[header] for header in headers])
    else:
        raise ValueError("Invalid data type. Should be either kinematics or kinetics or muscle_activations")


    # Colors for left and right sides
    colors = {2: 'rgba(255, 0, 0, 0.2)', 3: 'rgba(0, 0, 255, 0.2)' , 4: 'rgba(0, 255, 0, 0.2)', -1: 'rgba(0, 0, 0, 0.2)', 0: 'rgba(0, 0, 0, 0.2)' }
    colors_mean = {2: 'rgba(255, 0, 0, 1.0)', 3: 'rgba(0, 0, 255, 1.0)' , 4: 'rgba(0, 255, 0, 1.0)', -1: 'rgba(0, 0, 0, 1.0)', 0: 'rgba(0, 0, 0, 1.0)'}

    y_max = 0 
    y_min = 0 

    # Create each subplot
    for i, header in enumerate(headers):
        row = i // num_cols + 1
        col = i % num_cols + 1
        
        if i >= len(headers): 
            break
        
        if 'muscle_activations' in data_type:
            title = plot_muscle_activations_mapping[header]
        elif data_type == 'kinematics' or data_type == 'kinetics':
            title = plot_names_mapping[header]
        else:
            raise ValueError("Invalid data type. Should be either kinematics or kinetics or muscle_activations")

        # Plot every kinematics data
        x = None

        for mcs_score in mcs_aggregate_data: 
            if len(mcs_aggregate_data[mcs_score]) == 0: 
                continue  
            plot_data_mean = mcs_aggregate_data[mcs_score][data_type]['mean']
            plot_data_std = mcs_aggregate_data[mcs_score][data_type]['std']
            # print(plot_data_mean.shape)
            if x is None: 
                x = np.linspace(0,1,num=plot_data_mean[i].shape[-1]) 

            fig.add_trace(go.Scatter(x=x, y=plot_data_mean[i], showlegend = (i==len(headers)-1), 
                                    name=f'MCS:{mcs_score}',line=dict(color=colors_mean[mcs_score])), row=row, col=col)
            fig.add_trace(go.Scatter(x=list(x) + list(x)[::-1], 
                                        y=list(plot_data_mean[i] + np.array(plot_data_std[i]/2)) + list(np.array(plot_data_mean[i]) - np.array(plot_data_std[i]/2))[::-1] ,
                                            mode='lines', line=dict(width=0), name=f'MCS:{mcs_score} Bounds', showlegend=False, fill='toself',hoverinfo="skip",fillcolor=colors[mcs_score]), row=row, col=col)

            y_min = min(y_min, np.min(plot_data_mean[i] - plot_data_std[i]/2))
            y_max = max(y_max, np.max(plot_data_mean[i] + plot_data_std[i]/2))
            
        # Update y-axis label
        if data_type == 'kinematics':
            fig.update_yaxes(title_text='deg', row=row, col=col)
        elif data_type == 'kinetics':
            fig.update_yaxes(title_text='Nm', row=row, col=col)
        else:
            fig.update_yaxes(title_text='0-1', row=row, col=col)
        # fig.update_yaxes(title_text='deg', row=row, col=col)

        fig.update_xaxes(title_text='% SQT Cycle (Seconds)', row=row, col=col)

    

    # Update layout
    fig.update_layout(height=2000, width=1000,
                        showlegend=True,  title_x=0.5,
                        title_text=title_text,
                        font_family="Times New Roman",
                        font_color="black",
                        title_font_family="Times New Roman",
                        title_font_color="black")

    # fig.update_yaxes(range=[y_min,y_max])
    
    # Show the figure
    fig.show()
    
    return fig


for k in ['kinematics','kinetics']:
    fig = plot_mcs_distribution(plot_headers, mcs_aggregate_data, f"MCS {k} Distributions",data_type=k)
    plotly.io.write_image(fig, f'pdfs/mcs_subject_{k}_distribution.pdf', format='pdf')
    
for page_index,ma_page in enumerate(plot_muscle_activations_mapping_pages):
    k = f'muscle_activations-{page_index}'
    fig = plot_mcs_distribution(ma_page.keys(), mcs_aggregate_data, f"MCS {k} Distributions",data_type=k)
    plotly.io.write_image(fig, f'pdfs/mcs_subject_{k}_distribution.pdf', format='pdf')

# %% [markdown]
# # Plot all mcs lines

# %%
# Plot Per MCS data

from math import e


def plot_mcs_data(headers,mcs_aggregate_data,title_text="Plot Data",data_type="kinematics",num_cols=3, visualize=False, mcs_scores = None): 
    
    mcs_scores = mcs_aggregate_data.keys() if mcs_scores is None else mcs_scores

    # assert plot_data.shape[-1] == 101, "Length of data should be 101"
    num_rows = int(math.ceil(len(headers)/num_cols))

    # Create 4x4 subplots (we'll only use 14 of them)
    if data_type == 'kinematics' or data_type == 'kinetics':
        fig = make_subplots(rows=num_rows, cols=num_cols, subplot_titles=[plot_names_mapping[header] + ( ' moments' if data_type == 'kinetics' else '' ) for header in headers])
    elif  'muscle_activations' in data_type:
        fig = make_subplots(rows=num_rows, cols=num_cols, subplot_titles=[plot_muscle_activations_mapping[header] for header in headers])
    else:
        raise ValueError("Invalid data type. Should be either kinematics or kinetics or muscle_activations")
    

    colors = {2: 'rgba(255, 0, 0, 0.2)', 3: 'rgba(0, 0, 255, 0.2)' , 4: 'rgba(0, 255, 0, 0.2)', -1: 'rgba(0, 0, 0, 0.2)', 0: 'rgba(0, 0, 0, 0.2)' }
    colors_mean = {2: 'rgba(255, 0, 0, 1.0)', 3: 'rgba(0, 0, 255, 1.0)' , 4: 'rgba(0, 255, 0, 1.0)', -1: 'rgba(0, 0, 0, 0.1)', 0: 'rgba(0, 0, 0, 0.2)'}
    # Colors for left and right sides
    # colors = {2: 'rgba(255, 0, 0, 0.2)', 3: 'rgba(0, 0, 255, 0.2)' , 4: 'rgba(0, 255, 0, 0.2)', -1: 'rgba(0, 0, 0, 0.2)' }
    # colors_mean = {2: 'rgba(255, 0, 0, 1.0)', 3: 'rgba(0, 0, 255, 1.0)' , 4: 'rgba(0, 255, 0, 1.0)', -1: 'rgba(0, 0, 0, 1.0)'}

    y_min = 0 # Max value for y-axis
    y_max = 0 # Max value for y-axis

    # Create each subplot
    for i, header in enumerate(headers):
        row = i // num_cols + 1
        col = i % num_cols + 1
        
        if i >= len(headers): 
            break   
        
        if 'muscle_activations' in data_type:
            title = plot_muscle_activations_mapping[header]
        elif data_type == 'kinematics' or data_type == 'kinetics':
            title = plot_names_mapping[header]
        else: 
            raise ValueError("Invalid data type. Should be either kinematics or kinetics or muscle_activations")

        # Plot every kinematics data
        x = None

        for mcs_score in mcs_scores: 
            
            if data_type not in mcs_aggregate_data[mcs_score]: 
                continue 
            for y_ind, y in enumerate(mcs_aggregate_data[mcs_score][data_type]['list']):

                if x is None: 
                    x = np.linspace(0,1,num=y.shape[-1])                            

                show_lengend = (i==len(headers)-1) and y_ind==0 
                if show_lengend:
                    plot_name = f"MCS:{mcs_score}"
                else: 
                    plot_name = f'{mcs_aggregate_data[mcs_score][data_type]["ppe_names"][y_ind]}'

                fig.add_trace(go.Scatter(x=x, y=y[i], showlegend=show_lengend, 
                                        name=plot_name,line=dict(color=colors_mean[mcs_score])), row=row, col=col)
                y_min = min(y_min, y[i].min()) 
                y_max = max(y_max, y[i].max())
        # Update y-axis label
        if data_type == 'kinematics':
            fig.update_yaxes(title_text='deg', title_standoff=0, row=row, col=col)
        elif data_type == 'kinetics':
            fig.update_yaxes(title_text='Nm', title_standoff=0, row=row, col=col)
        else:
            fig.update_yaxes(title_text='0-1', title_standoff=0, row=row, col=col)

        fig.update_xaxes(title_text='% SQT Cycle (Seconds)', row=row, col=col)



    # Update layout
    # plot_width = 1800 if 'muscle_activations' in data_type else 1000
    # print("Setting y-axis range:",y_min,y_max)
    # fig.update_yaxes(range=[y_min, y_max])
    
    fig.update_layout(height=2000, width=1000,
                        showlegend=True,  title_x=0.5,
                        title_text=title_text,
                        font_family="Times New Roman",
                        font_color="black",
                        title_font_family="Times New Roman",
                        title_font_color="black",
                        )
    

    # Show the figure
    if visualize:
        fig.show()
    
    return fig


for k in ['kinematics','kinetics']:
    
    fig = plot_mcs_data(plot_headers, mcs_aggregate_data, f"MCS {k}",data_type=k,visualize=True)
    plotly.io.write_image(fig, f'pdfs/mcs_subject_{k}.pdf', format='pdf')
    
for page_index,ma_page in enumerate(plot_muscle_activations_mapping_pages):
    k = f'muscle_activations-{page_index}'
    fig = plot_mcs_data(ma_page.keys(), mcs_aggregate_data, f"MCS {k}",data_type=k,visualize=True, mcs_scores=[x for x in mcs_aggregate_data.keys() if x > 1])
    plotly.io.write_image(fig, f'pdfs/mcs_subject_{k}.pdf', format='pdf')

# %%
mcs_aggregate_data[mcs_score].keys()

# %%
from pypdf import PdfMerger
import glob

pdfs = os.listdir("pdfs")
pdfs = sorted(pdfs)

if ".ipynb_checkpoints" in pdfs:
    pdfs.remove(".ipynb_checkpoints")

for i in range(3,-1,-1):
    pdfs.remove(f"all_subject_muscle_activations-{i}.pdf")
    pdfs.insert(0,f"all_subject_muscle_activations-{i}.pdf")


pdfs.remove("all_subject_kinetics.pdf")
pdfs.insert(0,"all_subject_kinetics.pdf")

pdfs.remove("all_subject_kinematics.pdf")
pdfs.insert(0,"all_subject_kinematics.pdf")



for i in range(3,-1,-1):
    pdfs.remove(f"mcs_subject_muscle_activations-{i}.pdf")
    pdfs.insert(0,f"mcs_subject_muscle_activations-{i}.pdf")

pdfs.remove("mcs_subject_kinetics.pdf")
pdfs.insert(0,"mcs_subject_kinetics.pdf")

pdfs.remove("mcs_subject_kinematics.pdf")
pdfs.insert(0,"mcs_subject_kinematics.pdf")



for i in range(3,-1,-1):
    try:
        pdfs.remove(f"mcs_subject_muscle_activations-{i}_distribution.pdf")
        pdfs.insert(0,f"mcs_subject_muscle_activations-{i}_distribution.pdf")
    except Exception as e:
        print(f"mcs_subject_muscle_activations-{i}_distribution.pdf")
        

pdfs.remove("mcs_subject_kinetics_distribution.pdf")
pdfs.insert(0,"mcs_subject_kinetics_distribution.pdf")

pdfs.remove("mcs_subject_kinematics_distribution.pdf")
pdfs.insert(0,"mcs_subject_kinematics_distribution.pdf")


PPE_Subjects2session = {v:k for k,v in PPE_Subjects.items()}

# Remove individual plots for non mcs scores
keep_indices = []
for i in range(len(pdfs)):
    name = pdfs[i].split("_")[0]
    if name in PPE_Subjects2session: 
        # print(f"Checking:{name}")
        if PPE_Subjects2session[name] in mcs_scores and mcs_scores[PPE_Subjects2session[name]] > 1:
            # print(f"keep_indices:{name} MCS:{mcs_scores[PPE_Subjects2session[name]]}")
            keep_indices.append(i)
        else: 
            continue
    elif "subject" in pdfs[i]:
        keep_indices.append(i)
    

pdfs = [pdfs[i] for i in keep_indices]



merger = PdfMerger()

for pdf in pdfs:
    merger.append(os.path.join("pdfs",pdf))

merger.write("MCS-SQT-Muscle-Simulation.pdf")
merger.close()

# %% [markdown]
# # Plot the subject info

# %%
for mcs_score in mcs_aggregate_data:
    data_type = 'kinematics'
    if data_type not in mcs_aggregate_data[mcs_score]:
        print(mcs_score, {}, 0)
    else:
        subjects_set = set(mcs_aggregate_data[mcs_score][data_type]["ppe_names"])
        print(mcs_score, sorted(subjects_set), len(mcs_aggregate_data[mcs_score][data_type]["ppe_names"]))
